# %% [markdown]
# <a href="https://colab.research.google.com/github/Islam-hady9/deep-cuda/blob/master/cuda_cnn_image_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Cuda: Image Classification with CNN in CUDA
#
# **Author:** Islam Abd-Elhady
# **Date:** January 7, 2025
#
# ---
#
# ## Project Overview
#
# **Deep Cuda** is a cutting-edge project that harnesses the power of **CUDA (Compute Unified Device Architecture)** to implement a **Convolutional Neural Network (CNN)** for image classification. This project is designed to demonstrate how GPU acceleration can significantly improve the training and inference times of deep learning models. The focus of this implementation is on classifying handwritten digits from the popular **MNIST dataset** using a fully CUDA-accelerated pipeline.
#
# ---
#
# ## Key Features
#
# 1. **Custom CUDA Implementation**:
#    - All forward and backward propagation computations are implemented from scratch using CUDA kernels, demonstrating fine-grained control over GPU processing.
#
# 2. **Convolutional Neural Network Architecture**:
#    - A three-layer CNN:
#      - **Convolution Layer** for feature extraction.
#      - **Subsampling (Pooling) Layer** for dimensionality reduction.
#      - **Fully Connected Layer** for final classification.
#
# 3. **MNIST Dataset Integration**:
#    - Utilizes the MNIST dataset for training and testing.
#    - Supports efficient loading and preprocessing of dataset images.
#
# 4. **Performance Optimization**:
#    - GPU-accelerated matrix operations with libraries like `cublas`.
#    - Optimized kernels for activation functions, gradient computation, and weight updates.
#
# 5. **End-to-End Training and Evaluation**:
#    - Implements both the training loop (backpropagation) and testing loop.
#    - Outputs key metrics such as accuracy, error rate, and training time.
#
# ---
#
# ## Why CUDA?
#
# The project leverages **CUDA** for parallelized computations, enabling:
# - Faster execution by utilizing the GPU's massive parallelism.
# - Hands-on understanding of how deep learning operations can be optimized at the hardware level.
# - Demonstration of GPU programming for high-performance deep learning.
#
# ---
#
# ## Learning Outcomes
#
# By exploring **Deep Cuda**, you will:
# - Gain an in-depth understanding of CNNs and their implementation.
# - Learn how to write and optimize CUDA kernels for neural network operations.
# - Understand the principles of GPU acceleration for machine learning.
#
# ---
#
# ### Let's dive into the world of **Deep Cuda** and unleash the power of GPU acceleration for deep learning!

# %% [markdown]
# ### Check GPU Availability
#
# This cell checks the details of the NVIDIA GPU available on your Colab instance. The `nvidia-smi` command displays GPU information such as:
#
# - GPU name and model.
# - Driver version.
# - CUDA version.
# - GPU utilization and memory usage.
#
# This ensures that a compatible CUDA-enabled GPU is available for running the CNN project.

# %%
# !nvidia-smi
# Out:
# Tue Jan  7 08:14:22 2025
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   46C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# ### Install CUDA Toolkit
#
# This step updates the system package list and installs the CUDA Toolkit version 11.8. CUDA is essential for utilizing the GPU to accelerate deep learning computations and kernel execution in the CNN implementation.

# %%
# !apt-get update
# !apt-get install -y cuda-11-8
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [61.7 kB]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,199 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,631 kB]
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:13 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,226 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [3,652 kB]
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [3,513 kB]
# Get:17 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,552 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [2,854 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,517 kB]
# Fetched 19.6 MB in 4s (4,710 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   cpp-12 cuda-cccl-11-8 cuda-command-line-tools-11-8 cuda-compiler-11-8 cuda-cudart-11-8
#   cuda-cudart-dev-11-8 cuda-cuobjdump-11-8 cuda-cupti-11-8 cuda-cupti-dev-11-8 cuda-cuxxfilt-11-8
#   cuda-demo-suite-11-8 cuda-documentation-11-8 cuda-driver-dev-11-8 cuda-drivers cuda-drivers-565
#   cuda-gdb-11-8 cuda-libraries-11-8 cuda-libraries-dev-11-8 cuda-memcheck-11-8 cuda-nsight-11-8
#   cuda-nsight-compute-11-8 cuda-nsight-systems-11-8 cuda-nvcc-11-8 cuda-nvdisasm-11-8
#   cuda-nvml-dev-11-8 cuda-nvprof-11-8 cuda-nvprune-11-8 cuda-nvrtc-11-8 cuda-nvrtc-dev-11-8
#   cuda-nvtx-11-8 cuda-nvvp-11-8 cuda-profiler-api-11-8 cuda-runtime-11-8 cuda-sanitizer-11-8
#   cuda-toolkit-11-8 cuda-toolkit-11-8-config-common cuda-toolkit-11-config-common cuda-tools-11-8
#   cuda-visual-tools-11-8 dctrl-tools default-jre default-jre-headless dkms fakeroot
#   fonts-dejavu-core fonts-dejavu-extra gcc-12 gds-tools-11-8 keyboard-configuration libasan8
#   libatk-wrapper-java libatk-wrapper-java-jni libcublas-11-8 libcublas-dev-11-8 libcufft-11-8
#   libcufft-dev-11-8 libcufile-11-8 libcufile-dev-11-8 libcurand-11-8 libcurand-dev-11-8
#   libcusolver-11-8 libcusolver-dev-11-8 libcusparse-11-8 libcusparse-dev-11-8 libfakeroot
#   libfontenc1 libgail-common libgail18 libgcc-12-dev libgtk2.0-0 libgtk2.0-bin libgtk2.0-common
#   libjansson4 liblocale-gettext-perl libnpp-11-8 libnpp-dev-11-8 libnvidia-cfg1-565
#   libnvidia-common-565 libnvidia-compute-565 libnvidia-decode-565 libnvidia-encode-565
#   libnvidia-extra-565 libnvidia-fbc1-565 libnvidia-gl-565 libnvjpeg-11-8 libnvjpeg-dev-11-8
#   librsvg2-common libtinfo5 libtsan2 libudev1 libxcb-icccm4 libxcb-image0 libxcb-keysyms1
#   libxcb-render-util0 libxcb-util1 libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1 libxcvt0 libxfont2
#   libxkbcommon-x11-0 libxkbfile1 libxtst6 libxxf86dga1 nsight-compute-2022.3.0
#   nsight-systems-2022.4.2 nvidia-compute-utils-565 nvidia-dkms-565 nvidia-driver-565
#   nvidia-firmware-565-565.57.01 nvidia-kernel-common-565 nvidia-kernel-source-565 nvidia-modprobe
#   nvidia-prime nvidia-settings nvidia-utils-565 openjdk-11-jre python3-xkit screen-resolution-extra
#   systemd-hwe-hwdb udev x11-utils x11-xkb-utils xcvt xfonts-base xfonts-encodings xfonts-utils
#   xserver-common xserver-xorg-core xserver-xorg-video-nvidia-565
# Suggested packages:
#   gcc-12-locales cpp-12-doc debtags menu gcc-12-multilib gcc-12-doc gvfs mesa-utils xfs | xserver
#   xfonts-100dpi | xfonts-75dpi xfonts-scalable
# Recommended packages:
#   libnvidia-compute-565:i386 libnvidia-decode-565:i386 libnvidia-encode-565:i386
#   libnvidia-fbc1-565:i386 libnvidia-gl-565:i386
# The following NEW packages will be installed:
#   cpp-12 cuda-11-8 cuda-cccl-11-8 cuda-command-line-tools-11-8 cuda-compiler-11-8 cuda-cudart-11-8
#   cuda-cudart-dev-11-8 cuda-cuobjdump-11-8 cuda-cupti-11-8 cuda-cupti-dev-11-8 cuda-cuxxfilt-11-8
#   cuda-demo-suite-11-8 cuda-documentation-11-8 cuda-driver-dev-11-8 cuda-drivers cuda-drivers-565
#   cuda-gdb-11-8 cuda-libraries-11-8 cuda-libraries-dev-11-8 cuda-memcheck-11-8 cuda-nsight-11-8
#   cuda-nsight-compute-11-8 cuda-nsight-systems-11-8 cuda-nvcc-11-8 cuda-nvdisasm-11-8
#   cuda-nvml-dev-11-8 cuda-nvprof-11-8 cuda-nvprune-11-8 cuda-nvrtc-11-8 cuda-nvrtc-dev-11-8
#   cuda-nvtx-11-8 cuda-nvvp-11-8 cuda-profiler-api-11-8 cuda-runtime-11-8 cuda-sanitizer-11-8
#   cuda-toolkit-11-8 cuda-toolkit-11-8-config-common cuda-toolkit-11-config-common cuda-tools-11-8
#   cuda-visual-tools-11-8 dctrl-tools default-jre default-jre-headless dkms fakeroot
#   fonts-dejavu-core fonts-dejavu-extra gcc-12 gds-tools-11-8 keyboard-configuration libasan8
#   libatk-wrapper-java libatk-wrapper-java-jni libcublas-11-8 libcublas-dev-11-8 libcufft-11-8
#   libcufft-dev-11-8 libcufile-11-8 libcufile-dev-11-8 libcurand-11-8 libcurand-dev-11-8
#   libcusolver-11-8 libcusolver-dev-11-8 libcusparse-11-8 libcusparse-dev-11-8 libfakeroot
#   libfontenc1 libgail-common libgail18 libgcc-12-dev libgtk2.0-0 libgtk2.0-bin libgtk2.0-common
#   libjansson4 liblocale-gettext-perl libnpp-11-8 libnpp-dev-11-8 libnvidia-cfg1-565
#   libnvidia-common-565 libnvidia-compute-565 libnvidia-decode-565 libnvidia-encode-565
#   libnvidia-extra-565 libnvidia-fbc1-565 libnvidia-gl-565 libnvjpeg-11-8 libnvjpeg-dev-11-8
#   librsvg2-common libtinfo5 libtsan2 libxcb-icccm4 libxcb-image0 libxcb-keysyms1
#   libxcb-render-util0 libxcb-util1 libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1 libxcvt0 libxfont2
#   libxkbcommon-x11-0 libxkbfile1 libxtst6 libxxf86dga1 nsight-compute-2022.3.0
#   nsight-systems-2022.4.2 nvidia-compute-utils-565 nvidia-dkms-565 nvidia-driver-565
#   nvidia-firmware-565-565.57.01 nvidia-kernel-common-565 nvidia-kernel-source-565 nvidia-modprobe
#   nvidia-prime nvidia-settings nvidia-utils-565 openjdk-11-jre python3-xkit screen-resolution-extra
#   systemd-hwe-hwdb udev x11-utils x11-xkb-utils xcvt xfonts-base xfonts-encodings xfonts-utils
#   xserver-common xserver-xorg-core xserver-xorg-video-nvidia-565
# The following packages will be upgraded:
#   libudev1
# 1 upgraded, 130 newly installed, 0 to remove and 51 not upgraded.
# Need to get 3,075 MB of archives.
# After this operation, 7,706 MB of additional disk space will be used.
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-toolkit-11-config-common 11.8.89-1 [16.4 kB]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-toolkit-11-8-config-common 11.8.89-1 [16.3 kB]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cudart-11-8 11.8.89-1 [165 kB]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvrtc-11-8 11.8.89-1 [16.4 MB]
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcublas-11-8 11.11.3.6-1 [248 MB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblocale-gettext-perl amd64 1.07-4build3 [17.1 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 keyboard-configuration all 1.205ubuntu3 [206 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 cpp-12 amd64 12.3.0-1ubuntu1~22.04 [10.8 MB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libasan8 amd64 12.3.0-1ubuntu1~22.04 [2,442 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libtsan2 amd64 12.3.0-1ubuntu1~22.04 [2,477 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgcc-12-dev amd64 12.3.0-1ubuntu1~22.04 [2,618 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gcc-12 amd64 12.3.0-1ubuntu1~22.04 [21.7 MB]
# Get:13 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcufft-11-8 10.9.0.58-1 [94.2 MB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 dctrl-tools amd64 2.24-3build2 [66.9 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 dkms all 2.8.7-2ubuntu2.2 [70.1 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libudev1 amd64 249.11-0ubuntu3.12 [78.2 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 udev amd64 249.11-0ubuntu3.12 [1,557 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjansson4 amd64 2.13.1-1.1build3 [32.4 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbfile1 amd64 1:1.1.0-1build3 [71.8 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-xkb-utils amd64 7.7+5build4 [172 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 xserver-common all 2:21.1.4-2ubuntu1.7~22.04.12 [28.7 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcvt0 amd64 0.1.1-3 [5,494 B]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfontenc1 amd64 1:1.1.4-1build3 [14.7 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfont2 amd64 1:2.0.5-1build1 [94.5 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 xserver-xorg-core amd64 2:21.1.4-2ubuntu1.7~22.04.12 [1,477 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libtinfo5 amd64 6.3-2ubuntu0.1 [100 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinerama0 amd64 1.14-3ubuntu3 [5,414 B]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-icccm4 amd64 0.4.1-1.1build2 [11.5 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-util1 amd64 0.4.0-1build2 [11.4 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-image0 amd64 0.4.0-2 [11.5 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-keysyms1 amd64 0.4.0-1build3 [8,746 B]
# Get:32 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-render-util0 amd64 0.3.9-1build3 [10.3 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xkb1 amd64 1.14-3ubuntu3 [32.8 kB]
# Get:34 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcufile-11-8 1.4.0.31-1 [474 kB]
# Get:35 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcurand-11-8 10.3.0.86-1 [42.2 MB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbcommon-x11-0 amd64 1.4.0-1 [14.4 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinput0 amd64 1.14-3ubuntu3 [34.3 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy/main amd64 default-jre-headless amd64 2:1.11-72build2 [3,042 B]
# Get:39 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 openjdk-11-jre amd64 11.0.25+9-1ubuntu1~22.04 [216 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy/main amd64 default-jre amd64 2:1.11-72build2 [896 B]
# Get:42 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfakeroot amd64 1.28-1ubuntu1 [31.5 kB]
# Get:43 http://archive.ubuntu.com/ubuntu jammy/main amd64 fakeroot amd64 1.28-1ubuntu1 [60.4 kB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-core all 2.37-2build1 [1,041 kB]
# Get:45 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-extra all 2.37-2build1 [2,041 kB]
# Get:46 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxxf86dga1 amd64 2:1.1.5-0ubuntu3 [12.6 kB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-utils amd64 7.7+5build2 [206 kB]
# Get:48 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java all 0.38.0-5build1 [53.1 kB]
# Get:49 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java-jni amd64 0.38.0-5build1 [49.0 kB]
# Get:50 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk2.0-common all 2.24.33-2ubuntu2.1 [125 kB]
# Get:51 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk2.0-0 amd64 2.24.33-2ubuntu2.1 [2,038 kB]
# Get:52 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgail18 amd64 2.24.33-2ubuntu2.1 [15.9 kB]
# Get:53 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgail-common amd64 2.24.33-2ubuntu2.1 [132 kB]
# Get:54 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk2.0-bin amd64 2.24.33-2ubuntu2.1 [7,936 B]
# Get:55 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcusolver-11-8 11.4.1.48-1 [52.3 MB]
# Get:56 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 librsvg2-common amd64 2.52.5+dfsg-3ubuntu0.2 [17.7 kB]
# Get:57 http://archive.ubuntu.com/ubuntu jammy/main amd64 nvidia-prime all 0.8.17.1 [9,956 B]
# Get:58 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-xkit all 0.5.0ubuntu5 [18.5 kB]
# Get:59 http://archive.ubuntu.com/ubuntu jammy/main amd64 screen-resolution-extra all 0.18.2 [4,396 B]
# Get:60 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 systemd-hwe-hwdb all 249.11.5 [3,228 B]
# Get:61 http://archive.ubuntu.com/ubuntu jammy/main amd64 xcvt amd64 0.1.1-3 [7,140 B]
# Get:62 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-encodings all 1:1.0.5-0ubuntu2 [578 kB]
# Get:63 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-utils amd64 1:7.7+6build2 [94.6 kB]
# Get:64 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-base all 1:1.0.5 [5,896 kB]
# Get:65 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcusparse-11-8 11.7.5.86-1 [116 MB]
# Get:66 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnpp-11-8 11.8.0.86-1 [102 MB]
# Get:67 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvjpeg-11-8 11.9.0.86-1 [1,865 kB]
# Get:68 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-libraries-11-8 11.8.0-1 [2,518 B]
# Get:69 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-common-565 565.57.01-0ubuntu1 [15.7 kB]
# Get:70 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-decode-565 565.57.01-0ubuntu1 [2,105 kB]
# Get:71 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-compute-565 565.57.01-0ubuntu1 [55.6 MB]
# Get:72 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-gl-565 565.57.01-0ubuntu1 [139 MB]
# Get:73 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-kernel-source-565 565.57.01-0ubuntu1 [54.1 MB]
# Get:74 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-firmware-565-565.57.01 565.57.01-0ubuntu1 [48.4 MB]
# Get:75 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-modprobe 565.57.01-0ubuntu1 [21.7 kB]
# Get:76 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-kernel-common-565 565.57.01-0ubuntu1 [97.6 kB]
# Get:77 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-dkms-565 565.57.01-0ubuntu1 [34.4 kB]
# Get:78 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-extra-565 565.57.01-0ubuntu1 [71.5 kB]
# Get:79 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-compute-utils-565 565.57.01-0ubuntu1 [107 kB]
# Get:80 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-encode-565 565.57.01-0ubuntu1 [105 kB]
# Get:81 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-utils-565 565.57.01-0ubuntu1 [498 kB]
# Get:82 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-cfg1-565 565.57.01-0ubuntu1 [145 kB]
# Get:83 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  xserver-xorg-video-nvidia-565 565.57.01-0ubuntu1 [1,614 kB]
# Get:84 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-fbc1-565 565.57.01-0ubuntu1 [92.9 kB]
# Get:85 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-driver-565 565.57.01-0ubuntu1 [488 kB]
# Get:86 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-drivers-565 565.57.01-0ubuntu1 [2,546 B]
# Get:87 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-drivers 565.57.01-0ubuntu1 [2,494 B]
# Get:88 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-runtime-11-8 11.8.0-1 [2,424 B]
# Get:89 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cuobjdump-11-8 11.8.86-1 [165 kB]
# Get:90 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cuxxfilt-11-8 11.8.86-1 [189 kB]
# Get:91 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cccl-11-8 11.8.89-1 [1,040 kB]
# Get:92 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-driver-dev-11-8 11.8.89-1 [27.3 kB]
# Get:93 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cudart-dev-11-8 11.8.89-1 [820 kB]
# Get:94 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvcc-11-8 11.8.89-1 [43.5 MB]
# Get:95 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvprune-11-8 11.8.86-1 [58.1 kB]
# Get:96 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-compiler-11-8 11.8.0-1 [2,432 B]
# Get:97 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-profiler-api-11-8 11.8.86-1 [18.5 kB]
# Get:98 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvrtc-dev-11-8 11.8.89-1 [13.5 MB]
# Get:99 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcublas-dev-11-8 11.11.3.6-1 [269 MB]
# Get:100 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcufft-dev-11-8 10.9.0.58-1 [189 MB]
# Get:101 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcufile-dev-11-8 1.4.0.31-1 [1,062 kB]
# Get:102 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcurand-dev-11-8 10.3.0.86-1 [42.9 MB]
# Get:103 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcusolver-dev-11-8 11.4.1.48-1 [35.7 MB]
# Get:104 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcusparse-dev-11-8 11.7.5.86-1 [116 MB]
# Get:105 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnpp-dev-11-8 11.8.0.86-1 [100 MB]
# Get:106 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvjpeg-dev-11-8 11.9.0.86-1 [1,536 kB]
# Get:107 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-libraries-dev-11-8 11.8.0-1 [2,554 B]
# Get:108 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cupti-11-8 11.8.87-1 [15.4 MB]
# Get:109 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cupti-dev-11-8 11.8.87-1 [2,552 kB]
# Get:110 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvdisasm-11-8 11.8.86-1 [50.8 MB]
# Get:111 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-gdb-11-8 11.8.86-1 [4,138 kB]
# Get:112 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-memcheck-11-8 11.8.86-1 [142 kB]
# Get:113 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvprof-11-8 11.8.87-1 [1,959 kB]
# Get:114 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvtx-11-8 11.8.86-1 [51.3 kB]
# Get:115 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-sanitizer-11-8 11.8.86-1 [8,784 kB]
# Get:116 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-command-line-tools-11-8 11.8.0-1 [2,472 B]
# Get:117 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nsight-compute-2022.3.0 2022.3.0.22-1 [580 MB]
# Get:118 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nsight-compute-11-8 11.8.0-1 [3,790 B]
# Get:119 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nsight-systems-2022.4.2 2022.4.2.50-32196742v0 [286 MB]
# Get:120 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nsight-systems-11-8 11.8.0-1 [3,310 B]
# Get:121 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nsight-11-8 11.8.86-1 [119 MB]
# Get:122 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvml-dev-11-8 11.8.86-1 [81.4 kB]
# Get:123 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvvp-11-8 11.8.87-1 [114 MB]
# Get:124 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-visual-tools-11-8 11.8.0-1 [2,870 B]
# Get:125 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  gds-tools-11-8 1.4.0.31-1 [38.7 MB]
# Get:126 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-tools-11-8 11.8.0-1 [2,390 B]
# Get:127 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-documentation-11-8 11.8.86-1 [49.8 kB]
# Get:128 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-toolkit-11-8 11.8.0-1 [3,374 B]
# Get:129 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-demo-suite-11-8 11.8.86-1 [3,997 kB]
# Get:130 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-11-8 11.8.0-1 [2,450 B]
# Get:131 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-settings 565.57.01-0ubuntu1 [959 kB]
# Fetched 3,075 MB in 1min 7s (45.7 MB/s)
# Extracting templates from packages: 100%
# Preconfiguring packages ...
# Selecting previously unselected package liblocale-gettext-perl.
# (Reading database ... 123632 files and directories currently installed.)
# Preparing to unpack .../0-liblocale-gettext-perl_1.07-4build3_amd64.deb ...
# Unpacking liblocale-gettext-perl (1.07-4build3) ...
# Selecting previously unselected package keyboard-configuration.
# Preparing to unpack .../1-keyboard-configuration_1.205ubuntu3_all.deb ...
# Unpacking keyboard-configuration (1.205ubuntu3) ...
# Selecting previously unselected package cpp-12.
# Preparing to unpack .../2-cpp-12_12.3.0-1ubuntu1~22.04_amd64.deb ...
# Unpacking cpp-12 (12.3.0-1ubuntu1~22.04) ...
# Selecting previously unselected package libasan8:amd64.
# Preparing to unpack .../3-libasan8_12.3.0-1ubuntu1~22.04_amd64.deb ...
# Unpacking libasan8:amd64 (12.3.0-1ubuntu1~22.04) ...
# Selecting previously unselected package libtsan2:amd64.
# Preparing to unpack .../4-libtsan2_12.3.0-1ubuntu1~22.04_amd64.deb ...
# Unpacking libtsan2:amd64 (12.3.0-1ubuntu1~22.04) ...
# Selecting previously unselected package libgcc-12-dev:amd64.
# Preparing to unpack .../5-libgcc-12-dev_12.3.0-1ubuntu1~22.04_amd64.deb ...
# Unpacking libgcc-12-dev:amd64 (12.3.0-1ubuntu1~22.04) ...
# Selecting previously unselected package gcc-12.
# Preparing to unpack .../6-gcc-12_12.3.0-1ubuntu1~22.04_amd64.deb ...
# Unpacking gcc-12 (12.3.0-1ubuntu1~22.04) ...
# Selecting previously unselected package dctrl-tools.
# Preparing to unpack .../7-dctrl-tools_2.24-3build2_amd64.deb ...
# Unpacking dctrl-tools (2.24-3build2) ...
# Selecting previously unselected package dkms.
# Preparing to unpack .../8-dkms_2.8.7-2ubuntu2.2_all.deb ...
# Unpacking dkms (2.8.7-2ubuntu2.2) ...
# Preparing to unpack .../9-libudev1_249.11-0ubuntu3.12_amd64.deb ...
# Unpacking libudev1:amd64 (249.11-0ubuntu3.12) over (249.11-0ubuntu3.10) ...
# Setting up libudev1:amd64 (249.11-0ubuntu3.12) ...
# Selecting previously unselected package udev.
# (Reading database ... 123992 files and directories currently installed.)
# Preparing to unpack .../000-udev_249.11-0ubuntu3.12_amd64.deb ...
# Unpacking udev (249.11-0ubuntu3.12) ...
# Selecting previously unselected package libjansson4:amd64.
# Preparing to unpack .../001-libjansson4_2.13.1-1.1build3_amd64.deb ...
# Unpacking libjansson4:amd64 (2.13.1-1.1build3) ...
# Selecting previously unselected package cuda-toolkit-11-config-common.
# Preparing to unpack .../002-cuda-toolkit-11-config-common_11.8.89-1_all.deb ...
# Unpacking cuda-toolkit-11-config-common (11.8.89-1) ...
# Selecting previously unselected package cuda-toolkit-11-8-config-common.
# Preparing to unpack .../003-cuda-toolkit-11-8-config-common_11.8.89-1_all.deb ...
# Unpacking cuda-toolkit-11-8-config-common (11.8.89-1) ...
# Selecting previously unselected package cuda-cudart-11-8.
# Preparing to unpack .../004-cuda-cudart-11-8_11.8.89-1_amd64.deb ...
# Unpacking cuda-cudart-11-8 (11.8.89-1) ...
# Selecting previously unselected package cuda-nvrtc-11-8.
# Preparing to unpack .../005-cuda-nvrtc-11-8_11.8.89-1_amd64.deb ...
# Unpacking cuda-nvrtc-11-8 (11.8.89-1) ...
# Selecting previously unselected package libcublas-11-8.
# Preparing to unpack .../006-libcublas-11-8_11.11.3.6-1_amd64.deb ...
# Unpacking libcublas-11-8 (11.11.3.6-1) ...
# Selecting previously unselected package libcufft-11-8.
# Preparing to unpack .../007-libcufft-11-8_10.9.0.58-1_amd64.deb ...
# Unpacking libcufft-11-8 (10.9.0.58-1) ...
# Selecting previously unselected package libcufile-11-8.
# Preparing to unpack .../008-libcufile-11-8_1.4.0.31-1_amd64.deb ...
# Unpacking libcufile-11-8 (1.4.0.31-1) ...
# Selecting previously unselected package libcurand-11-8.
# Preparing to unpack .../009-libcurand-11-8_10.3.0.86-1_amd64.deb ...
# Unpacking libcurand-11-8 (10.3.0.86-1) ...
# Selecting previously unselected package libcusolver-11-8.
# Preparing to unpack .../010-libcusolver-11-8_11.4.1.48-1_amd64.deb ...
# Unpacking libcusolver-11-8 (11.4.1.48-1) ...
# Selecting previously unselected package libcusparse-11-8.
# Preparing to unpack .../011-libcusparse-11-8_11.7.5.86-1_amd64.deb ...
# Unpacking libcusparse-11-8 (11.7.5.86-1) ...
# Selecting previously unselected package libnpp-11-8.
# Preparing to unpack .../012-libnpp-11-8_11.8.0.86-1_amd64.deb ...
# Unpacking libnpp-11-8 (11.8.0.86-1) ...
# Selecting previously unselected package libnvjpeg-11-8.
# Preparing to unpack .../013-libnvjpeg-11-8_11.9.0.86-1_amd64.deb ...
# Unpacking libnvjpeg-11-8 (11.9.0.86-1) ...
# Selecting previously unselected package cuda-libraries-11-8.
# Preparing to unpack .../014-cuda-libraries-11-8_11.8.0-1_amd64.deb ...
# Unpacking cuda-libraries-11-8 (11.8.0-1) ...
# Selecting previously unselected package libnvidia-common-565.
# Preparing to unpack .../015-libnvidia-common-565_565.57.01-0ubuntu1_all.deb ...
# Unpacking libnvidia-common-565 (565.57.01-0ubuntu1) ...
# Selecting previously unselected package libnvidia-decode-565:amd64.
# Preparing to unpack .../016-libnvidia-decode-565_565.57.01-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-decode-565:amd64 (565.57.01-0ubuntu1) ...
# Selecting previously unselected package libnvidia-compute-565:amd64.
# Preparing to unpack .../017-libnvidia-compute-565_565.57.01-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-compute-565:amd64 (565.57.01-0ubuntu1) ...
# Selecting previously unselected package libnvidia-gl-565:amd64.
# Preparing to unpack .../018-libnvidia-gl-565_565.57.01-0ubuntu1_amd64.deb ...
# dpkg-query: no packages found matching libnvidia-gl-535
# Unpacking libnvidia-gl-565:amd64 (565.57.01-0ubuntu1) ...
# Selecting previously unselected package nvidia-kernel-source-565.
# Preparing to unpack .../019-nvidia-kernel-source-565_565.57.01-0ubuntu1_amd64.deb ...
# Unpacking nvidia-kernel-source-565 (565.57.01-0ubuntu1) ...
# Selecting previously unselected package nvidia-firmware-565-565.57.01.
# Preparing to unpack .../020-nvidia-firmware-565-565.57.01_565.57.01-0ubuntu1_amd64.deb ...
# Unpacking nvidia-firmware-565-565.57.01 (565.57.01-0ubuntu1) ...
# Selecting previously unselected package nvidia-modprobe.
# Preparing to unpack .../021-nvidia-modprobe_565.57.01-0ubuntu1_amd64.deb ...
# Unpacking nvidia-modprobe (565.57.01-0ubuntu1) ...
# Selecting previously unselected package nvidia-kernel-common-565.
# Preparing to unpack .../022-nvidia-kernel-common-565_565.57.01-0ubuntu1_amd64.deb ...
# Unpacking nvidia-kernel-common-565 (565.57.01-0ubuntu1) ...
# Selecting previously unselected package nvidia-dkms-565.
# Preparing to unpack .../023-nvidia-dkms-565_565.57.01-0ubuntu1_amd64.deb ...
# Unpacking nvidia-dkms-565 (565.57.01-0ubuntu1) ...
# Selecting previously unselected package libnvidia-extra-565:amd64.
# Preparing to unpack .../024-libnvidia-extra-565_565.57.01-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-extra-565:amd64 (565.57.01-0ubuntu1) ...
# Selecting previously unselected package nvidia-compute-utils-565.
# Preparing to unpack .../025-nvidia-compute-utils-565_565.57.01-0ubuntu1_amd64.deb ...
# Unpacking nvidia-compute-utils-565 (565.57.01-0ubuntu1) ...
# Selecting previously unselected package libnvidia-encode-565:amd64.
# Preparing to unpack .../026-libnvidia-encode-565_565.57.01-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-encode-565:amd64 (565.57.01-0ubuntu1) ...
# Selecting previously unselected package nvidia-utils-565.
# Preparing to unpack .../027-nvidia-utils-565_565.57.01-0ubuntu1_amd64.deb ...
# Unpacking nvidia-utils-565 (565.57.01-0ubuntu1) ...
# Selecting previously unselected package libnvidia-cfg1-565:amd64.
# Preparing to unpack .../028-libnvidia-cfg1-565_565.57.01-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-cfg1-565:amd64 (565.57.01-0ubuntu1) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../029-libxkbfile1_1%3a1.1.0-1build3_amd64.deb ...
# Unpacking libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Selecting previously unselected package x11-xkb-utils.
# Preparing to unpack .../030-x11-xkb-utils_7.7+5build4_amd64.deb ...
# Unpacking x11-xkb-utils (7.7+5build4) ...
# Selecting previously unselected package xserver-common.
# Preparing to unpack .../031-xserver-common_2%3a21.1.4-2ubuntu1.7~22.04.12_all.deb ...
# Unpacking xserver-common (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Selecting previously unselected package libxcvt0:amd64.
# Preparing to unpack .../032-libxcvt0_0.1.1-3_amd64.deb ...
# Unpacking libxcvt0:amd64 (0.1.1-3) ...
# Selecting previously unselected package libfontenc1:amd64.
# Preparing to unpack .../033-libfontenc1_1%3a1.1.4-1build3_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.4-1build3) ...
# Selecting previously unselected package libxfont2:amd64.
# Preparing to unpack .../034-libxfont2_1%3a2.0.5-1build1_amd64.deb ...
# Unpacking libxfont2:amd64 (1:2.0.5-1build1) ...
# Selecting previously unselected package xserver-xorg-core.
# Preparing to unpack .../035-xserver-xorg-core_2%3a21.1.4-2ubuntu1.7~22.04.12_amd64.deb ...
# Unpacking xserver-xorg-core (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Selecting previously unselected package xserver-xorg-video-nvidia-565.
# Preparing to unpack .../036-xserver-xorg-video-nvidia-565_565.57.01-0ubuntu1_amd64.deb ...
# Unpacking xserver-xorg-video-nvidia-565 (565.57.01-0ubuntu1) ...
# Selecting previously unselected package libnvidia-fbc1-565:amd64.
# Preparing to unpack .../037-libnvidia-fbc1-565_565.57.01-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-fbc1-565:amd64 (565.57.01-0ubuntu1) ...
# Selecting previously unselected package nvidia-driver-565.
# Preparing to unpack .../038-nvidia-driver-565_565.57.01-0ubuntu1_amd64.deb ...
# Unpacking nvidia-driver-565 (565.57.01-0ubuntu1) ...
# Selecting previously unselected package cuda-drivers-565.
# Preparing to unpack .../039-cuda-drivers-565_565.57.01-0ubuntu1_amd64.deb ...
# Unpacking cuda-drivers-565 (565.57.01-0ubuntu1) ...
# Selecting previously unselected package cuda-drivers.
# Preparing to unpack .../040-cuda-drivers_565.57.01-0ubuntu1_amd64.deb ...
# Unpacking cuda-drivers (565.57.01-0ubuntu1) ...
# Selecting previously unselected package cuda-runtime-11-8.
# Preparing to unpack .../041-cuda-runtime-11-8_11.8.0-1_amd64.deb ...
# Unpacking cuda-runtime-11-8 (11.8.0-1) ...
# Selecting previously unselected package cuda-cuobjdump-11-8.
# Preparing to unpack .../042-cuda-cuobjdump-11-8_11.8.86-1_amd64.deb ...
# Unpacking cuda-cuobjdump-11-8 (11.8.86-1) ...
# Selecting previously unselected package cuda-cuxxfilt-11-8.
# Preparing to unpack .../043-cuda-cuxxfilt-11-8_11.8.86-1_amd64.deb ...
# Unpacking cuda-cuxxfilt-11-8 (11.8.86-1) ...
# Selecting previously unselected package cuda-cccl-11-8.
# Preparing to unpack .../044-cuda-cccl-11-8_11.8.89-1_amd64.deb ...
# Unpacking cuda-cccl-11-8 (11.8.89-1) ...
# Selecting previously unselected package cuda-driver-dev-11-8.
# Preparing to unpack .../045-cuda-driver-dev-11-8_11.8.89-1_amd64.deb ...
# Unpacking cuda-driver-dev-11-8 (11.8.89-1) ...
# Selecting previously unselected package cuda-cudart-dev-11-8.
# Preparing to unpack .../046-cuda-cudart-dev-11-8_11.8.89-1_amd64.deb ...
# Unpacking cuda-cudart-dev-11-8 (11.8.89-1) ...
# Selecting previously unselected package cuda-nvcc-11-8.
# Preparing to unpack .../047-cuda-nvcc-11-8_11.8.89-1_amd64.deb ...
# Unpacking cuda-nvcc-11-8 (11.8.89-1) ...
# Selecting previously unselected package cuda-nvprune-11-8.
# Preparing to unpack .../048-cuda-nvprune-11-8_11.8.86-1_amd64.deb ...
# Unpacking cuda-nvprune-11-8 (11.8.86-1) ...
# Selecting previously unselected package cuda-compiler-11-8.
# Preparing to unpack .../049-cuda-compiler-11-8_11.8.0-1_amd64.deb ...
# Unpacking cuda-compiler-11-8 (11.8.0-1) ...
# Selecting previously unselected package cuda-profiler-api-11-8.
# Preparing to unpack .../050-cuda-profiler-api-11-8_11.8.86-1_amd64.deb ...
# Unpacking cuda-profiler-api-11-8 (11.8.86-1) ...
# Selecting previously unselected package cuda-nvrtc-dev-11-8.
# Preparing to unpack .../051-cuda-nvrtc-dev-11-8_11.8.89-1_amd64.deb ...
# Unpacking cuda-nvrtc-dev-11-8 (11.8.89-1) ...
# Selecting previously unselected package libcublas-dev-11-8.
# Preparing to unpack .../052-libcublas-dev-11-8_11.11.3.6-1_amd64.deb ...
# Unpacking libcublas-dev-11-8 (11.11.3.6-1) ...
# Selecting previously unselected package libcufft-dev-11-8.
# Preparing to unpack .../053-libcufft-dev-11-8_10.9.0.58-1_amd64.deb ...
# Unpacking libcufft-dev-11-8 (10.9.0.58-1) ...
# Selecting previously unselected package libcufile-dev-11-8.
# Preparing to unpack .../054-libcufile-dev-11-8_1.4.0.31-1_amd64.deb ...
# Unpacking libcufile-dev-11-8 (1.4.0.31-1) ...
# Selecting previously unselected package libcurand-dev-11-8.
# Preparing to unpack .../055-libcurand-dev-11-8_10.3.0.86-1_amd64.deb ...
# Unpacking libcurand-dev-11-8 (10.3.0.86-1) ...
# Selecting previously unselected package libcusolver-dev-11-8.
# Preparing to unpack .../056-libcusolver-dev-11-8_11.4.1.48-1_amd64.deb ...
# Unpacking libcusolver-dev-11-8 (11.4.1.48-1) ...
# Selecting previously unselected package libcusparse-dev-11-8.
# Preparing to unpack .../057-libcusparse-dev-11-8_11.7.5.86-1_amd64.deb ...
# Unpacking libcusparse-dev-11-8 (11.7.5.86-1) ...
# Selecting previously unselected package libnpp-dev-11-8.
# Preparing to unpack .../058-libnpp-dev-11-8_11.8.0.86-1_amd64.deb ...
# Unpacking libnpp-dev-11-8 (11.8.0.86-1) ...
# Selecting previously unselected package libnvjpeg-dev-11-8.
# Preparing to unpack .../059-libnvjpeg-dev-11-8_11.9.0.86-1_amd64.deb ...
# Unpacking libnvjpeg-dev-11-8 (11.9.0.86-1) ...
# Selecting previously unselected package cuda-libraries-dev-11-8.
# Preparing to unpack .../060-cuda-libraries-dev-11-8_11.8.0-1_amd64.deb ...
# Unpacking cuda-libraries-dev-11-8 (11.8.0-1) ...
# Selecting previously unselected package cuda-cupti-11-8.
# Preparing to unpack .../061-cuda-cupti-11-8_11.8.87-1_amd64.deb ...
# Unpacking cuda-cupti-11-8 (11.8.87-1) ...
# Selecting previously unselected package cuda-cupti-dev-11-8.
# Preparing to unpack .../062-cuda-cupti-dev-11-8_11.8.87-1_amd64.deb ...
# Unpacking cuda-cupti-dev-11-8 (11.8.87-1) ...
# Selecting previously unselected package cuda-nvdisasm-11-8.
# Preparing to unpack .../063-cuda-nvdisasm-11-8_11.8.86-1_amd64.deb ...
# Unpacking cuda-nvdisasm-11-8 (11.8.86-1) ...
# Selecting previously unselected package cuda-gdb-11-8.
# Preparing to unpack .../064-cuda-gdb-11-8_11.8.86-1_amd64.deb ...
# Unpacking cuda-gdb-11-8 (11.8.86-1) ...
# Selecting previously unselected package cuda-memcheck-11-8.
# Preparing to unpack .../065-cuda-memcheck-11-8_11.8.86-1_amd64.deb ...
# Unpacking cuda-memcheck-11-8 (11.8.86-1) ...
# Selecting previously unselected package cuda-nvprof-11-8.
# Preparing to unpack .../066-cuda-nvprof-11-8_11.8.87-1_amd64.deb ...
# Unpacking cuda-nvprof-11-8 (11.8.87-1) ...
# Selecting previously unselected package cuda-nvtx-11-8.
# Preparing to unpack .../067-cuda-nvtx-11-8_11.8.86-1_amd64.deb ...
# Unpacking cuda-nvtx-11-8 (11.8.86-1) ...
# Selecting previously unselected package cuda-sanitizer-11-8.
# Preparing to unpack .../068-cuda-sanitizer-11-8_11.8.86-1_amd64.deb ...
# Unpacking cuda-sanitizer-11-8 (11.8.86-1) ...
# Selecting previously unselected package cuda-command-line-tools-11-8.
# Preparing to unpack .../069-cuda-command-line-tools-11-8_11.8.0-1_amd64.deb ...
# Unpacking cuda-command-line-tools-11-8 (11.8.0-1) ...
# Selecting previously unselected package nsight-compute-2022.3.0.
# Preparing to unpack .../070-nsight-compute-2022.3.0_2022.3.0.22-1_amd64.deb ...
# Unpacking nsight-compute-2022.3.0 (2022.3.0.22-1) ...
# Selecting previously unselected package cuda-nsight-compute-11-8.
# Preparing to unpack .../071-cuda-nsight-compute-11-8_11.8.0-1_amd64.deb ...
# Unpacking cuda-nsight-compute-11-8 (11.8.0-1) ...
# Selecting previously unselected package libtinfo5:amd64.
# Preparing to unpack .../072-libtinfo5_6.3-2ubuntu0.1_amd64.deb ...
# Unpacking libtinfo5:amd64 (6.3-2ubuntu0.1) ...
# Selecting previously unselected package libxcb-xinerama0:amd64.
# Preparing to unpack .../073-libxcb-xinerama0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxcb-icccm4:amd64.
# Preparing to unpack .../074-libxcb-icccm4_0.4.1-1.1build2_amd64.deb ...
# Unpacking libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# Selecting previously unselected package libxcb-util1:amd64.
# Preparing to unpack .../075-libxcb-util1_0.4.0-1build2_amd64.deb ...
# Unpacking libxcb-util1:amd64 (0.4.0-1build2) ...
# Selecting previously unselected package libxcb-image0:amd64.
# Preparing to unpack .../076-libxcb-image0_0.4.0-2_amd64.deb ...
# Unpacking libxcb-image0:amd64 (0.4.0-2) ...
# Selecting previously unselected package libxcb-keysyms1:amd64.
# Preparing to unpack .../077-libxcb-keysyms1_0.4.0-1build3_amd64.deb ...
# Unpacking libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# Selecting previously unselected package libxcb-render-util0:amd64.
# Preparing to unpack .../078-libxcb-render-util0_0.3.9-1build3_amd64.deb ...
# Unpacking libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Selecting previously unselected package libxcb-xkb1:amd64.
# Preparing to unpack .../079-libxcb-xkb1_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxkbcommon-x11-0:amd64.
# Preparing to unpack .../080-libxkbcommon-x11-0_1.4.0-1_amd64.deb ...
# Unpacking libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Selecting previously unselected package libxcb-xinput0:amd64.
# Preparing to unpack .../081-libxcb-xinput0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package nsight-systems-2022.4.2.
# Preparing to unpack .../082-nsight-systems-2022.4.2_2022.4.2.50-32196742v0_amd64.deb ...
# Unpacking nsight-systems-2022.4.2 (2022.4.2.50-32196742v0) ...
# Selecting previously unselected package cuda-nsight-systems-11-8.
# Preparing to unpack .../083-cuda-nsight-systems-11-8_11.8.0-1_amd64.deb ...
# Unpacking cuda-nsight-systems-11-8 (11.8.0-1) ...
# Selecting previously unselected package default-jre-headless.
# Preparing to unpack .../084-default-jre-headless_2%3a1.11-72build2_amd64.deb ...
# Unpacking default-jre-headless (2:1.11-72build2) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../085-libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package openjdk-11-jre:amd64.
# Preparing to unpack .../086-openjdk-11-jre_11.0.25+9-1ubuntu1~22.04_amd64.deb ...
# Unpacking openjdk-11-jre:amd64 (11.0.25+9-1ubuntu1~22.04) ...
# Selecting previously unselected package default-jre.
# Preparing to unpack .../087-default-jre_2%3a1.11-72build2_amd64.deb ...
# Unpacking default-jre (2:1.11-72build2) ...
# Selecting previously unselected package cuda-nsight-11-8.
# Preparing to unpack .../088-cuda-nsight-11-8_11.8.86-1_amd64.deb ...
# Unpacking cuda-nsight-11-8 (11.8.86-1) ...
# Selecting previously unselected package cuda-nvml-dev-11-8.
# Preparing to unpack .../089-cuda-nvml-dev-11-8_11.8.86-1_amd64.deb ...
# Unpacking cuda-nvml-dev-11-8 (11.8.86-1) ...
# Selecting previously unselected package cuda-nvvp-11-8.
# Preparing to unpack .../090-cuda-nvvp-11-8_11.8.87-1_amd64.deb ...
# Unpacking cuda-nvvp-11-8 (11.8.87-1) ...
# Selecting previously unselected package cuda-visual-tools-11-8.
# Preparing to unpack .../091-cuda-visual-tools-11-8_11.8.0-1_amd64.deb ...
# Unpacking cuda-visual-tools-11-8 (11.8.0-1) ...
# Selecting previously unselected package gds-tools-11-8.
# Preparing to unpack .../092-gds-tools-11-8_1.4.0.31-1_amd64.deb ...
# Unpacking gds-tools-11-8 (1.4.0.31-1) ...
# Selecting previously unselected package cuda-tools-11-8.
# Preparing to unpack .../093-cuda-tools-11-8_11.8.0-1_amd64.deb ...
# Unpacking cuda-tools-11-8 (11.8.0-1) ...
# Selecting previously unselected package cuda-documentation-11-8.
# Preparing to unpack .../094-cuda-documentation-11-8_11.8.86-1_amd64.deb ...
# Unpacking cuda-documentation-11-8 (11.8.86-1) ...
# Selecting previously unselected package cuda-toolkit-11-8.
# Preparing to unpack .../095-cuda-toolkit-11-8_11.8.0-1_amd64.deb ...
# Unpacking cuda-toolkit-11-8 (11.8.0-1) ...
# Selecting previously unselected package cuda-demo-suite-11-8.
# Preparing to unpack .../096-cuda-demo-suite-11-8_11.8.86-1_amd64.deb ...
# Unpacking cuda-demo-suite-11-8 (11.8.86-1) ...
# Selecting previously unselected package cuda-11-8.
# Preparing to unpack .../097-cuda-11-8_11.8.0-1_amd64.deb ...
# Unpacking cuda-11-8 (11.8.0-1) ...
# Selecting previously unselected package libfakeroot:amd64.
# Preparing to unpack .../098-libfakeroot_1.28-1ubuntu1_amd64.deb ...
# Unpacking libfakeroot:amd64 (1.28-1ubuntu1) ...
# Selecting previously unselected package fakeroot.
# Preparing to unpack .../099-fakeroot_1.28-1ubuntu1_amd64.deb ...
# Unpacking fakeroot (1.28-1ubuntu1) ...
# Selecting previously unselected package fonts-dejavu-core.
# Preparing to unpack .../100-fonts-dejavu-core_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-2build1) ...
# Selecting previously unselected package fonts-dejavu-extra.
# Preparing to unpack .../101-fonts-dejavu-extra_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-extra (2.37-2build1) ...
# Selecting previously unselected package libxxf86dga1:amd64.
# Preparing to unpack .../102-libxxf86dga1_2%3a1.1.5-0ubuntu3_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../103-x11-utils_7.7+5build2_amd64.deb ...
# Unpacking x11-utils (7.7+5build2) ...
# Selecting previously unselected package libatk-wrapper-java.
# Preparing to unpack .../104-libatk-wrapper-java_0.38.0-5build1_all.deb ...
# Unpacking libatk-wrapper-java (0.38.0-5build1) ...
# Selecting previously unselected package libatk-wrapper-java-jni:amd64.
# Preparing to unpack .../105-libatk-wrapper-java-jni_0.38.0-5build1_amd64.deb ...
# Unpacking libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Selecting previously unselected package libgtk2.0-common.
# Preparing to unpack .../106-libgtk2.0-common_2.24.33-2ubuntu2.1_all.deb ...
# Unpacking libgtk2.0-common (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgtk2.0-0:amd64.
# Preparing to unpack .../107-libgtk2.0-0_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgtk2.0-0:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgail18:amd64.
# Preparing to unpack .../108-libgail18_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgail18:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgail-common:amd64.
# Preparing to unpack .../109-libgail-common_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgail-common:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgtk2.0-bin.
# Preparing to unpack .../110-libgtk2.0-bin_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgtk2.0-bin (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package librsvg2-common:amd64.
# Preparing to unpack .../111-librsvg2-common_2.52.5+dfsg-3ubuntu0.2_amd64.deb ...
# Unpacking librsvg2-common:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Selecting previously unselected package nvidia-prime.
# Preparing to unpack .../112-nvidia-prime_0.8.17.1_all.deb ...
# Unpacking nvidia-prime (0.8.17.1) ...
# Selecting previously unselected package python3-xkit.
# Preparing to unpack .../113-python3-xkit_0.5.0ubuntu5_all.deb ...
# Unpacking python3-xkit (0.5.0ubuntu5) ...
# Selecting previously unselected package screen-resolution-extra.
# Preparing to unpack .../114-screen-resolution-extra_0.18.2_all.deb ...
# Unpacking screen-resolution-extra (0.18.2) ...
# Selecting previously unselected package nvidia-settings.
# Preparing to unpack .../115-nvidia-settings_565.57.01-0ubuntu1_amd64.deb ...
# Unpacking nvidia-settings (565.57.01-0ubuntu1) ...
# Selecting previously unselected package systemd-hwe-hwdb.
# Preparing to unpack .../116-systemd-hwe-hwdb_249.11.5_all.deb ...
# Unpacking systemd-hwe-hwdb (249.11.5) ...
# Selecting previously unselected package xcvt.
# Preparing to unpack .../117-xcvt_0.1.1-3_amd64.deb ...
# Unpacking xcvt (0.1.1-3) ...
# Selecting previously unselected package xfonts-encodings.
# Preparing to unpack .../118-xfonts-encodings_1%3a1.0.5-0ubuntu2_all.deb ...
# Unpacking xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Selecting previously unselected package xfonts-utils.
# Preparing to unpack .../119-xfonts-utils_1%3a7.7+6build2_amd64.deb ...
# Unpacking xfonts-utils (1:7.7+6build2) ...
# Selecting previously unselected package xfonts-base.
# Preparing to unpack .../120-xfonts-base_1%3a1.0.5_all.deb ...
# Unpacking xfonts-base (1:1.0.5) ...
# Setting up cpp-12 (12.3.0-1ubuntu1~22.04) ...
# Setting up libnvidia-common-565 (565.57.01-0ubuntu1) ...
# Setting up cuda-nvml-dev-11-8 (11.8.86-1) ...
# Setting up default-jre-headless (2:1.11-72build2) ...
# Setting up cuda-toolkit-11-config-common (11.8.89-1) ...
# Setting up libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# Setting up cuda-cccl-11-8 (11.8.89-1) ...
# Setting up cuda-cuobjdump-11-8 (11.8.86-1) ...
# Setting up libnvidia-cfg1-565:amd64 (565.57.01-0ubuntu1) ...
# Setting up cuda-nvrtc-11-8 (11.8.89-1) ...
# Setting up cuda-sanitizer-11-8 (11.8.86-1) ...
# Setting up nvidia-prime (0.8.17.1) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up nvidia-kernel-source-565 (565.57.01-0ubuntu1) ...
# Setting up nvidia-firmware-565-565.57.01 (565.57.01-0ubuntu1) ...
# Setting up cuda-cupti-11-8 (11.8.87-1) ...
# Setting up libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# Setting up libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Setting up libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Setting up openjdk-11-jre:amd64 (11.0.25+9-1ubuntu1~22.04) ...
# Setting up cuda-nvdisasm-11-8 (11.8.86-1) ...
# Setting up libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# Setting up libnvidia-fbc1-565:amd64 (565.57.01-0ubuntu1) ...
# Setting up default-jre (2:1.11-72build2) ...
# Setting up libnvidia-extra-565:amd64 (565.57.01-0ubuntu1) ...
# Setting up cuda-cuxxfilt-11-8 (11.8.86-1) ...
# Setting up libfakeroot:amd64 (1.28-1ubuntu1) ...
# Setting up libxcb-util1:amd64 (0.4.0-1build2) ...
# Setting up libjansson4:amd64 (2.13.1-1.1build3) ...
# Setting up libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Setting up nvidia-modprobe (565.57.01-0ubuntu1) ...
# Setting up libxcb-image0:amd64 (0.4.0-2) ...
# Setting up fakeroot (1.28-1ubuntu1) ...
# update-alternatives: using /usr/bin/fakeroot-sysv to provide /usr/bin/fakeroot (fakeroot) in auto mode
# Setting up libfontenc1:amd64 (1:1.1.4-1build3) ...
# Setting up libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# Setting up cuda-nvvp-11-8 (11.8.87-1) ...
# Setting up cuda-nvtx-11-8 (11.8.86-1) ...
# Setting up xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Setting up cuda-gdb-11-8 (11.8.86-1) ...
# Setting up cuda-toolkit-11-8-config-common (11.8.89-1) ...
# Setting alternatives
# update-alternatives: using /usr/local/cuda-11.8 to provide /usr/local/cuda-11 (cuda-11) in auto mode
# Setting up libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Setting up udev (249.11-0ubuntu3.12) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up libcusolver-11-8 (11.4.1.48-1) ...
# Setting up cuda-nvrtc-dev-11-8 (11.8.89-1) ...
# Setting up fonts-dejavu-core (2.37-2build1) ...
# Setting up librsvg2-common:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Setting up nvidia-kernel-common-565 (565.57.01-0ubuntu1) ...
# Created symlink /etc/systemd/system/systemd-hibernate.service.wants/nvidia-hibernate.service → /lib/systemd/system/nvidia-hibernate.service.
# Created symlink /etc/systemd/system/systemd-suspend.service.wants/nvidia-resume.service → /lib/systemd/system/nvidia-resume.service.
# Created symlink /etc/systemd/system/systemd-hibernate.service.wants/nvidia-resume.service → /lib/systemd/system/nvidia-resume.service.
# Created symlink /etc/systemd/system/systemd-suspend.service.wants/nvidia-suspend.service → /lib/systemd/system/nvidia-suspend.service.
# Setting up cuda-driver-dev-11-8 (11.8.89-1) ...
# Setting up systemd-hwe-hwdb (249.11.5) ...
# Setting up cuda-memcheck-11-8 (11.8.86-1) ...
# Setting up fonts-dejavu-extra (2.37-2build1) ...
# Setting up gds-tools-11-8 (1.4.0.31-1) ...
# Setting up cuda-nsight-11-8 (11.8.86-1) ...
# Setting up cuda-profiler-api-11-8 (11.8.86-1) ...
# Setting up libasan8:amd64 (12.3.0-1ubuntu1~22.04) ...
# Setting up libxcvt0:amd64 (0.1.1-3) ...
# Setting up libgtk2.0-common (2.24.33-2ubuntu2.1) ...
# Setting up cuda-documentation-11-8 (11.8.86-1) ...
# Setting up libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Setting up libtsan2:amd64 (12.3.0-1ubuntu1~22.04) ...
# Setting up python3-xkit (0.5.0ubuntu5) ...
# Setting up libtinfo5:amd64 (6.3-2ubuntu0.1) ...
# Setting up cuda-nvprune-11-8 (11.8.86-1) ...
# Setting up cuda-cudart-11-8 (11.8.89-1) ...
# Setting up libxfont2:amd64 (1:2.0.5-1build1) ...
# Setting up libnvjpeg-11-8 (11.9.0.86-1) ...
# Setting up liblocale-gettext-perl (1.07-4build3) ...
# Setting up dctrl-tools (2.24-3build2) ...
# Setting up cuda-nvprof-11-8 (11.8.87-1) ...
# Setting up nsight-compute-2022.3.0 (2022.3.0.22-1) ...
# Setting up nsight-systems-2022.4.2 (2022.4.2.50-32196742v0) ...
# update-alternatives: using /opt/nvidia/nsight-systems/2022.4.2/target-linux-x64/nsys to provide /usr/local/bin/nsys (nsys) in auto mode
# update-alternatives: using /opt/nvidia/nsight-systems/2022.4.2/host-linux-x64/nsys-ui to provide /usr/local/bin/nsys-ui (nsys-ui) in auto mode
# Setting up libcusparse-11-8 (11.7.5.86-1) ...
# Setting up libcufft-11-8 (10.9.0.58-1) ...
# Setting up cuda-cupti-dev-11-8 (11.8.87-1) ...
# Setting up libcufft-dev-11-8 (10.9.0.58-1) ...
# Setting up cuda-cudart-dev-11-8 (11.8.89-1) ...
# Setting up x11-xkb-utils (7.7+5build4) ...
# Setting up libnpp-11-8 (11.8.0.86-1) ...
# Setting up libcusolver-dev-11-8 (11.4.1.48-1) ...
# Setting up libgtk2.0-0:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up xfonts-utils (1:7.7+6build2) ...
# Setting up xcvt (0.1.1-3) ...
# Setting up cuda-nsight-systems-11-8 (11.8.0-1) ...
# Setting up cuda-command-line-tools-11-8 (11.8.0-1) ...
# Setting up libcusparse-dev-11-8 (11.7.5.86-1) ...
# Setting up xfonts-base (1:1.0.5) ...
# Setting up libcurand-11-8 (10.3.0.86-1) ...
# Setting up libcufile-11-8 (1.4.0.31-1) ...
# Setting alternatives
# Setting up libcublas-11-8 (11.11.3.6-1) ...
# Setting up libnpp-dev-11-8 (11.8.0.86-1) ...
# Setting up libgcc-12-dev:amd64 (12.3.0-1ubuntu1~22.04) ...
# Setting up cuda-libraries-11-8 (11.8.0-1) ...
# Setting up cuda-nsight-compute-11-8 (11.8.0-1) ...
# Setting up screen-resolution-extra (0.18.2) ...
# Setting up libgail18:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libgtk2.0-bin (2.24.33-2ubuntu2.1) ...
# Setting up x11-utils (7.7+5build2) ...
# Setting up nvidia-settings (565.57.01-0ubuntu1) ...
# Setting up libnvjpeg-dev-11-8 (11.9.0.86-1) ...
# Setting up libatk-wrapper-java (0.38.0-5build1) ...
# Setting up xserver-common (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Setting up keyboard-configuration (1.205ubuntu3) ...
# Your console font configuration will be updated the next time your system
# boots. If you want to update it now, run 'setupcon' from a virtual console.
# Setting up cuda-nvcc-11-8 (11.8.89-1) ...
# Setting up libgail-common:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up xserver-xorg-core (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Setting up libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Setting up libcublas-dev-11-8 (11.11.3.6-1) ...
# Setting up libcurand-dev-11-8 (10.3.0.86-1) ...
# Setting up libcufile-dev-11-8 (1.4.0.31-1) ...
# Setting up gcc-12 (12.3.0-1ubuntu1~22.04) ...
# Setting up cuda-compiler-11-8 (11.8.0-1) ...
# Setting up xserver-xorg-video-nvidia-565 (565.57.01-0ubuntu1) ...
# Setting up cuda-libraries-dev-11-8 (11.8.0-1) ...
# Setting up dkms (2.8.7-2ubuntu2.2) ...
# Setting up cuda-visual-tools-11-8 (11.8.0-1) ...
# Setting up nvidia-dkms-565 (565.57.01-0ubuntu1) ...
# Loading new nvidia-565.57.01 DKMS files...
# It is likely that 6.1.85+ belongs to a chroot's host
# Building for 5.15.0-130-generic
# Building for architecture x86_64
# Building initial module for 5.15.0-130-generic
# Done.
#
# nvidia.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/5.15.0-130-generic/updates/dkms/
#
# nvidia-modeset.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/5.15.0-130-generic/updates/dkms/
#
# nvidia-drm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/5.15.0-130-generic/updates/dkms/
#
# nvidia-uvm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/5.15.0-130-generic/updates/dkms/
#
# nvidia-peermem.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/5.15.0-130-generic/updates/dkms/
#
# depmod...
# Setting up cuda-tools-11-8 (11.8.0-1) ...
# Setting up cuda-toolkit-11-8 (11.8.0-1) ...
# Setting alternatives
# Setting up libnvidia-decode-565:amd64 (565.57.01-0ubuntu1) ...
# Setting up libnvidia-compute-565:amd64 (565.57.01-0ubuntu1) ...
# Setting up libnvidia-gl-565:amd64 (565.57.01-0ubuntu1) ...
# Setting up libnvidia-encode-565:amd64 (565.57.01-0ubuntu1) ...
# Setting up nvidia-utils-565 (565.57.01-0ubuntu1) ...
# Setting up nvidia-compute-utils-565 (565.57.01-0ubuntu1) ...
# Setting up nvidia-driver-565 (565.57.01-0ubuntu1) ...
# Setting up cuda-drivers-565 (565.57.01-0ubuntu1) ...
# Setting up cuda-drivers (565.57.01-0ubuntu1) ...
# Setting up cuda-runtime-11-8 (11.8.0-1) ...
# Setting up cuda-demo-suite-11-8 (11.8.86-1) ...
# Setting up cuda-11-8 (11.8.0-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libgdk-pixbuf-2.0-0:amd64 (2.42.8+dfsg-1ubuntu0.3) ...

# %% [markdown]
# ### Download MNIST Dataset Using PyTorch
#
# **Description:**
# This cell downloads the MNIST dataset using PyTorch's `torchvision` library and stores it in the specified directory. The MNIST dataset is used for training and testing the CNN model.
#
# ---
#
# **Key Components:**
#
# 1. **Import Libraries:**
#    - **`torch`:** Core library for machine learning and deep learning operations.
#    - **`torchvision.datasets`:** Provides access to commonly used datasets like MNIST.
#    - **`torchvision.transforms`:** Includes utilities for data transformation and preprocessing.
#
# 2. **Dataset Folder:**
#    - **`data_folder`:** Specifies the folder where the dataset will be stored. In this case, the folder is named `"data"`.
#
# 3. **Train Dataset:**
#    - **`datasets.MNIST`:** Downloads the training dataset.
#      - **`root`:** Directory where the dataset will be stored.
#      - **`train=True`:** Specifies that the training dataset should be downloaded.
#      - **`download=True`:** Enables downloading the dataset if it's not already present.
#      - **`transform=transforms.ToTensor()`:** Converts the image data into a PyTorch tensor for processing.
#
# 4. **Test Dataset:**
#    - Similarly downloads the test dataset by setting **`train=False`**.
#
# 5. **Print Confirmation:**
#    - Outputs a confirmation message indicating the dataset has been successfully downloaded and saved in the specified folder.

# %%
import torch
from torchvision import datasets, transforms

# Download the MNIST dataset
data_folder = "data"
train_dataset = datasets.MNIST(
    root=data_folder,
    train=True,
    download=True,
    transform=transforms.ToTensor()
)

test_dataset = datasets.MNIST(
    root=data_folder,
    train=False,
    download=True,
    transform=transforms.ToTensor()
)

print(f"Downloaded MNIST dataset to {data_folder}")
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 16.1MB/s]
# Extracting data/MNIST/raw/train-images-idx3-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 490kB/s]
# Extracting data/MNIST/raw/train-labels-idx1-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 4.45MB/s]
# Extracting data/MNIST/raw/t10k-images-idx3-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 8.46MB/s]
# Extracting data/MNIST/raw/t10k-labels-idx1-ubyte.gz to data/MNIST/raw
#
# Downloaded MNIST dataset to data

# %% [markdown]
# ### Define Layer Class and CUDA Kernels
#
# **Description:**
# This cell writes the `layer.h` file, which defines the structure of the `Layer` class and declares various CUDA kernels for implementing a Convolutional Neural Network (CNN). The `Layer` class represents a single layer in the CNN, and the CUDA kernels are responsible for forward and backward propagation.
#
# ---
#
# **Key Components:**
#
# 1. **Layer Class:**
#    - Contains properties for weights, biases, outputs, and gradients.
#    - Includes methods for:
#      - Clearing memory (`clear`).
#      - Setting outputs (`setOutput`).
#      - Backpropagation-specific operations (`bp_clear`).
#
# 2. **CUDA Utility Functions:**
#    - Kernels like `apply_step_function` and `apply_grad` are used for:
#      - Applying activation functions.
#      - Updating weights during training.
#
# 3. **Forward Propagation Kernels:**
#    - Kernels such as `fp_preact_c1` and `fp_bias_f` handle computations for:
#      - Convolutional layers.
#      - Fully connected layers during the forward pass.
#
# 4. **Backward Propagation Kernels:**
#    - Kernels like `bp_weight_f` and `bp_bias_c1` compute:
#      - Gradients for weight updates.
#      - Bias adjustments during backpropagation.

# %%
# %%writefile layer.h
#
# #include <cstdlib>
# #include <vector>
# #include <memory>
# #include <cublas_v2.h>
# #include <cuda.h>
#
# #ifndef LAYER_H
# #define LAYER_H
# #endif
#
# // Constants for learning rate (dt) and error threshold
# const static float dt = 1.0E-01f;        // Learning rate for gradient descent
# const static float threshold = 1.0E-02f; // Threshold for stopping training
#
# // Definition of the Layer class, which represents a single layer in the CNN
# class Layer {
#     public:
#     int M, N, O; // Dimensions:
#                  // M: Number of input neurons
#                  // N: Number of output neurons
#                  // O: Total number of outputs (for example, after flattening)
#
#     float *output;   // Layer's output values
#     float *preact;   // Pre-activation values (before applying activation function)
#
#     float *bias;     // Bias values for the layer
#     float *weight;   // Weight matrix for the layer
#
#     float *d_output; // Gradients of the output (used during backpropagation)
#     float *d_preact; // Gradients of the pre-activation values
#     float *d_weight; // Gradients of the weights
#
#     // Constructor: Initializes the layer with dimensions and allocates memory
#     Layer(int M, int N, int O);
#
#     // Destructor: Frees GPU memory associated with the layer
#     ~Layer();
#
#     // Method to set the output values (for example, from input data)
#     void setOutput(float *data);
#
#     // Clears the output and pre-activation values (sets them to zero)
#     void clear();
#
#     // Clears gradients (used during backpropagation to reset gradients)
#     void bp_clear();
# };
#
# // Utility CUDA kernel functions
# __device__ float step_function(float v); // Device function for activation (sigmoid)
# __global__ void apply_step_function(float *input, float *output, const int N); // Apply activation function
# __global__ void makeError(float *err, float *output, unsigned int Y, const int N); // Compute error gradient
# __global__ void apply_grad(float *output, float *grad, const int N); // Apply gradient to weights or biases
#
# // Forward propagation CUDA kernels (used for calculating activations)
# __global__ void fp_preact_c1(float input[28][28], float preact[6][24][24], float weight[6][5][5]); // Conv1 layer
# __global__ void fp_bias_c1(float preact[6][24][24], float bias[6]);                               // Add bias for Conv1
# __global__ void fp_preact_s1(float input[6][24][24], float preact[6][6][6], float weight[1][4][4]); // Pooling1 layer
# __global__ void fp_bias_s1(float preact[6][6][6], float bias[1]);                                 // Add bias for Pooling1
# __global__ void fp_preact_f(float input[6][6][6], float preact[10], float weight[10][6][6][6]);   // Fully connected layer
# __global__ void fp_bias_f(float preact[10], float bias[10]);                                      // Add bias for Fully connected
#
# // Backpropagation CUDA kernels (used for computing gradients)
# __global__ void bp_weight_f(float d_weight[10][6][6][6], float d_preact[10], float p_output[6][6][6]); // Gradients for fully connected weights
# __global__ void bp_bias_f(float bias[10], float d_preact[10]);                                         // Gradients for fully connected biases
# __global__ void bp_output_s1(float d_output[6][6][6], float n_weight[10][6][6][6], float nd_preact[10]); // Backprop from fully connected to pooling
# __global__ void bp_preact_s1(float d_preact[6][6][6], float d_output[6][6][6], float preact[6][6][6]);   // Gradients for pooling layer pre-activation
# __global__ void bp_weight_s1(float d_weight[1][4][4], float d_preact[6][6][6], float p_output[6][24][24]); // Gradients for pooling layer weights
# __global__ void bp_bias_s1(float bias[1], float d_preact[6][6][6]);                                     // Gradients for pooling layer biases
# __global__ void bp_output_c1(float d_output[6][24][24], float n_weight[1][4][4], float nd_preact[6][6][6]); // Backprop from pooling to convolution
# __global__ void bp_preact_c1(float d_preact[6][24][24], float d_output[6][24][24], float preact[6][24][24]); // Gradients for convolution layer pre-activation
# __global__ void bp_weight_c1(float d_weight[6][5][5], float d_preact[6][24][24], float p_output[28][28]);   // Gradients for convolution weights
# __global__ void bp_bias_c1(float bias[6], float d_preact[6][24][24]);                                     // Gradients for convolution biases
# Out:
# Writing layer.h

# %% [markdown]
# ### Define and Implement CUDA Kernels and Layer Methods
#
# **Description:**
# This cell writes the `layer.cu` file, which implements the methods of the `Layer` class and defines the CUDA kernels for the Convolutional Neural Network (CNN). It includes forward and backward propagation kernels, as well as utility functions for activation and gradient updates.
#
# ---
#
# **Key Components:**
#
# 1. **Layer Class Methods:**
#    - **Constructor:** Initializes layer dimensions and allocates GPU memory for weights, biases, and outputs.
#    - **Destructor:** Frees allocated GPU memory for weights, biases, and outputs.
#    - **setOutput():** Transfers input data to the GPU.
#    - **clear():** Resets output and pre-activation memory for forward propagation.
#    - **bp_clear():** Resets memory for backpropagation, including gradients.
#
# 2. **Utility CUDA Functions:**
#    - **`step_function`:** Implements the sigmoid activation function.
#    - **`apply_step_function`:** Applies the activation function to the layer's outputs.
#    - **`makeError`:** Computes the error signal for backpropagation.
#    - **`apply_grad`:** Updates weights and biases using computed gradients.
#
# 3. **Forward Propagation Kernels:**
#    - **`fp_preact_c1`:** Computes the pre-activation for the first convolutional layer.
#    - **`fp_bias_c1`:** Adds biases to the pre-activation of the first convolutional layer.
#    - Similar kernels exist for the subsampling and fully connected layers (e.g., `fp_preact_s1`, `fp_bias_f`).
#
# 4. **Backward Propagation Kernels:**
#    - **`bp_weight_f`:** Calculates the gradients of weights in the fully connected layer.
#    - **`bp_bias_f`:** Updates the biases in the fully connected layer.
#    - Similar kernels handle backpropagation for the subsampling and convolutional layers (e.g., `bp_weight_c1`, `bp_bias_s1`).
#
# 5. **Atomic Operations:**
#    - Atomic functions like `atomicAdd` are used in kernels for gradient aggregation during backpropagation.
#
# 6. **CUDA Memory Management:**
#    - Memory for weights, biases, outputs, and gradients is dynamically allocated and managed on the GPU using `cudaMalloc` and `cudaFree`.

# %%
# %%writefile layer.cu
#
# #include "layer.h"
#
# // Constructor: Initializes the layer with dimensions and allocates memory for weights, biases, and outputs
# Layer::Layer(int M, int N, int O)
# {
# 	this->M = M; // Number of input connections
# 	this->N = N; // Number of neurons
# 	this->O = O; // Number of outputs
#
# 	// Host-side arrays for bias and weight initialization
# 	float h_bias[N];
# 	float h_weight[N][M];
#
# 	// Initialize pointers to NULL
# 	output = NULL;
# 	preact = NULL;
# 	bias = NULL;
# 	weight = NULL;
#
# 	// Initialize biases and weights randomly
# 	for (int i = 0; i < N; ++i) {
# 		h_bias[i] = 0.5f - float(rand()) / float(RAND_MAX); // Random bias between -0.5 and 0.5
# 		for (int j = 0; j < M; ++j) {
# 			h_weight[i][j] = 0.5f - float(rand()) / float(RAND_MAX); // Random weight between -0.5 and 0.5
# 		}
# 	}
#
# 	// Allocate GPU memory for layer variables
# 	cudaMalloc(&output, sizeof(float) * O);
# 	cudaMalloc(&preact, sizeof(float) * O);
# 	cudaMalloc(&bias, sizeof(float) * N);
# 	cudaMalloc(&weight, sizeof(float) * M * N);
# 	cudaMalloc(&d_output, sizeof(float) * O);
# 	cudaMalloc(&d_preact, sizeof(float) * O);
# 	cudaMalloc(&d_weight, sizeof(float) * M * N);
#
# 	// Copy biases and weights from host to device
# 	cudaMemcpy(bias, h_bias, sizeof(float) * N, cudaMemcpyHostToDevice);
# 	cudaMemcpy(weight, h_weight, sizeof(float) * M * N, cudaMemcpyHostToDevice);
# }
#
# // Destructor: Frees allocated GPU memory for the layer
# Layer::~Layer()
# {
# 	cudaFree(output);
# 	cudaFree(preact);
# 	cudaFree(bias);
# 	cudaFree(weight);
# 	cudaFree(d_output);
# 	cudaFree(d_preact);
# 	cudaFree(d_weight);
# }
#
# // Sends a single data row to the GPU
# void Layer::setOutput(float *data)
# {
# 	cudaMemcpy(output, data, sizeof(float) * O, cudaMemcpyHostToDevice);
# }
#
# // Resets GPU memory for the current layer (clears output and preactivation values)
# void Layer::clear()
# {
# 	cudaMemset(output, 0x00, sizeof(float) * O);
# 	cudaMemset(preact, 0x00, sizeof(float) * O);
# }
#
# // Resets gradients and preactivation derivatives during backpropagation
# void Layer::bp_clear()
# {
# 	cudaMemset(d_output, 0x00, sizeof(float) * O);
# 	cudaMemset(d_preact, 0x00, sizeof(float) * O);
# 	cudaMemset(d_weight, 0x00, sizeof(float) * M * N);
# }
#
# // CUDA device function: Applies a sigmoid activation function
# __device__ float step_function(float v)
# {
# 	return 1 / (1 + exp(-v));
# }
#
# // CUDA kernel: Applies the step function to an array
# __global__ void apply_step_function(float *input, float *output, const int N)
# {
# 	const int pos = blockIdx.x * blockDim.x + threadIdx.x;
# 	const int size = blockDim.x * gridDim.x;
#
# 	// Process elements in parallel
# 	for (int idx = N * pos / size; idx < N * (pos + 1) / size; ++idx) {
# 		output[idx] = step_function(input[idx]);
# 	}
# }
#
# // CUDA kernel: Computes the error for the output layer
# __global__ void makeError(float *err, float *output, unsigned int Y, const int N)
# {
# 	const int pos = blockIdx.x * blockDim.x + threadIdx.x;
# 	const int size = blockDim.x * gridDim.x;
#
# 	// Compute error for each output neuron
# 	for (int idx = N * pos / size; idx < N * (pos + 1) / size; ++idx) {
# 		err[idx] = ((Y == idx ? 1.0f : 0.0f) - output[idx]);
# 	}
# }
#
# // CUDA kernel: Applies gradient updates to weights
# __global__ void apply_grad(float *output, float *grad, const int N)
# {
# 	const int pos = blockIdx.x * blockDim.x + threadIdx.x;
# 	const int size = blockDim.x * gridDim.x;
#
# 	// Update each weight in parallel
# 	for (int idx = N * pos / size; idx < N * (pos + 1) / size; ++idx) {
# 		output[idx] += dt * grad[idx]; // Update with learning rate `dt`
# 	}
# }
#
# // CUDA kernel: Forward propagation for convolutional layer (c1)
# __global__ void fp_preact_c1(float input[28][28], float preact[6][24][24], float weight[6][5][5])
# {
# 	const int pos = blockIdx.x * blockDim.x + threadIdx.x;
# 	const int size = blockDim.x * gridDim.x;
#
# 	const int N = 5 * 5 * 6 * 24 * 24;
#
# 	// Convolution operation
# 	for (int n = N * pos / size; n < N * (pos + 1) / size; ++n) {
# 		int idx = n;
# 		const int i1 = ((idx /= 1) % 5);
# 		const int i2 = ((idx /= 5) % 5);
# 		const int i3 = ((idx /= 5) % 6);
# 		const int i4 = ((idx /= 6) % 24);
# 		const int i5 = ((idx /= 24) % 24);
#
# 		// Accumulate preactivation using weights and input
# 		atomicAdd(&preact[i3][i4][i5], weight[i3][i1][i2] * input[i4 + i1][i5 + i2]);
# 	}
# }
#
# // CUDA kernel: Adds bias to preactivations for the convolutional layer
# __global__ void fp_bias_c1(float preact[6][24][24], float bias[6])
# {
# 	const int pos = blockIdx.x * blockDim.x + threadIdx.x;
# 	const int size = blockDim.x * gridDim.x;
#
# 	const int N = 6 * 24 * 24;
#
# 	// Add bias to preactivation in parallel
# 	for (int n = N * pos / size; n < N * (pos + 1) / size; ++n) {
# 		int idx = n;
# 		const int i1 = ((idx /= 1) % 6);
# 		const int i2 = ((idx /= 6) % 24);
# 		const int i3 = ((idx /= 24) % 24);
#
# 		preact[i1][i2][i3] += bias[i1];
# 	}
# }
#
# // CUDA kernel: Forward propagation for the subsampling layer (s1)
# __global__ void fp_preact_s1(float input[6][24][24], float preact[6][6][6], float weight[1][4][4])
# {
# 	const int pos = blockIdx.x * blockDim.x + threadIdx.x;
# 	const int size = blockDim.x * gridDim.x;
#
# 	const int N = 4 * 4 * 6 * 6 * 6;
#
# 	// Subsampling operation
# 	for (int n = N * pos / size; n < N * (pos + 1) / size; ++n) {
# 		int idx = n;
# 		const int i1 = ((idx /= 1) % 4);
# 		const int i2 = ((idx /= 4) % 4);
# 		const int i3 = ((idx /= 4) % 6);
# 		const int i4 = ((idx /= 6) % 6);
# 		const int i5 = ((idx /= 6) % 6);
#
# 		// Accumulate preactivation from the subsampled input
# 		atomicAdd(&preact[i3][i4][i5], weight[0][i1][i2] * input[i3][i4 * 4 + i1][i5 * 4 + i2]);
# 	}
# }
#
# // CUDA kernel: Adds bias to preactivations for the subsampling layer
# __global__ void fp_bias_s1(float preact[6][6][6], float bias[1])
# {
# 	const int pos = blockIdx.x * blockDim.x + threadIdx.x;
# 	const int size = blockDim.x * gridDim.x;
#
# 	const int N = 6 * 6 * 6;
#
# 	// Add bias to preactivation in parallel
# 	for (int n = N * pos / size; n < N * (pos + 1) / size; ++n) {
# 		int idx = n;
# 		const int i1 = ((idx /= 1) % 6);
# 		const int i2 = ((idx /= 6) % 6);
# 		const int i3 = ((idx /= 6) % 6);
#
# 		preact[i1][i2][i3] += bias[0];
# 	}
# }
#
# // CUDA kernel: Forward propagation for the fully connected layer (f)
# __global__ void fp_preact_f(float input[6][6][6], float preact[10], float weight[10][6][6][6])
# {
# 	const int pos = blockIdx.x * blockDim.x + threadIdx.x;
# 	const int size = blockDim.x * gridDim.x;
#
# 	const int N = 10 * 6 * 6 * 6;
#
# 	// Fully connected operation
# 	for (int n = N * pos / size; n < N * (pos + 1) / size; ++n) {
# 		int idx = n;
# 		const int i1 = ((idx /= 1) % 10);
# 		const int i2 = ((idx /= 10) % 6);
# 		const int i3 = ((idx /= 6) % 6);
# 		const int i4 = ((idx /= 6) % 6);
#
# 		// Accumulate preactivation
# 		atomicAdd(&preact[i1], weight[i1][i2][i3][i4] * input[i2][i3][i4]);
# 	}
# }
#
# // CUDA kernel: Adds bias to preactivations for the fully connected layer
# __global__ void fp_bias_f(float preact[10], float bias[10])
# {
# 	const int pos = blockIdx.x * blockDim.x + threadIdx.x;
# 	const int size = blockDim.x * gridDim.x;
#
# 	const int N = 10;
#
# 	// Add bias to preactivation in parallel
# 	for (int idx = N * pos / size; idx < N * (pos + 1) / size; ++idx) {
# 		preact[idx] += bias[idx];
# 	}
# }
#
# // Backpropagation: Compute weight gradients for the fully connected layer
# __global__ void bp_weight_f(float d_weight[10][6][6][6], float d_preact[10], float p_output[6][6][6])
# {
# 	const int pos = blockIdx.x * blockDim.x + threadIdx.x;
# 	const int size = blockDim.x * gridDim.x;
#
# 	const int N = 10 * 6 * 6 * 6;
#
# 	// Compute weight gradients
# 	for (int n = N * pos / size; n < N * (pos + 1) / size; ++n) {
# 		int idx = n;
# 		const int i1 = ((idx /= 1) % 10);
# 		const int i2 = ((idx /= 10) % 6);
# 		const int i3 = ((idx /= 6) % 6);
# 		const int i4 = ((idx /= 6) % 6);
#
# 		d_weight[i1][i2][i3][i4] = d_preact[i1] * p_output[i2][i3][i4];
# 	}
# }
#
# // Backpropagation: Compute bias gradients for the fully connected layer
# __global__ void bp_bias_f(float bias[10], float d_preact[10])
# {
# 	const int pos = blockIdx.x * blockDim.x + threadIdx.x;
# 	const int size = blockDim.x * gridDim.x;
#
# 	const int N = 10;
#
# 	// Update bias with gradients
# 	for (int idx = N * pos / size; idx < N * (pos + 1) / size; ++idx) {
# 		bias[idx] += dt * d_preact[idx];
# 	}
# }
#
# // Backpropagation: Propagate output error for the subsampling layer (s1)
# __global__ void bp_output_s1(float d_output[6][6][6], float n_weight[10][6][6][6], float nd_preact[10])
# {
# 	const int pos = blockIdx.x * blockDim.x + threadIdx.x;
# 	const int size = blockDim.x * gridDim.x;
#
# 	const int N = 10 * 6 * 6 * 6;
#
# 	// Propagate error backward
# 	for (int n = N * pos / size; n < N * (pos + 1) / size; ++n) {
# 		int idx = n;
# 		const int i1 = ((idx /= 1) % 10);
# 		const int i2 = ((idx /= 10) % 6);
# 		const int i3 = ((idx /= 6) % 6);
# 		const int i4 = ((idx /= 6) % 6);
#
# 		atomicAdd(&d_output[i2][i3][i4], n_weight[i1][i2][i3][i4] * nd_preact[i1]);
# 	}
# }
#
# // Backpropagation: Compute preactivation gradients for the subsampling layer
# __global__ void bp_preact_s1(float d_preact[6][6][6], float d_output[6][6][6], float preact[6][6][6])
# {
# 	const int pos = blockIdx.x * blockDim.x + threadIdx.x;
# 	const int size = blockDim.x * gridDim.x;
#
# 	const int N = 6 * 6 * 6;
#
# 	// Compute gradient of preactivation
# 	for (int n = N * pos / size; n < N * (pos + 1) / size; ++n) {
# 		int idx = n;
# 		const int i1 = ((idx /= 1) % 6);
# 		const int i2 = ((idx /= 6) % 6);
# 		const int i3 = ((idx /= 6) % 6);
#
# 		const float o = step_function(preact[i1][i2][i3]);
#
# 		d_preact[i1][i2][i3] = d_output[i1][i2][i3] * o * (1 - o); // Sigmoid derivative
# 	}
# }
#
# // Backpropagation: Compute weight gradients for the subsampling layer (s1)
# __global__ void bp_weight_s1(float d_weight[1][4][4], float d_preact[6][6][6], float p_output[6][24][24])
# {
# 	const int pos = blockIdx.x * blockDim.x + threadIdx.x;
# 	const int size = blockDim.x * gridDim.x;
#
# 	const int N = 1 * 4 * 4 * 6 * 6 * 6;
# 	const float d = pow(6.0f, 3.0f); // Normalization factor
#
# 	// Compute weight gradients
# 	for (int n = N * pos / size; n < N * (pos + 1) / size; ++n) {
# 		int idx = n;
# 		const int i1 = ((idx /= 1) % 1);
# 		const int i2 = ((idx /= 1) % 4);
# 		const int i3 = ((idx /= 4) % 4);
# 		const int i4 = ((idx /= 4) % 6);
# 		const int i5 = ((idx /= 6) % 6);
# 		const int i6 = ((idx /= 6) % 6);
#
# 		atomicAdd(&d_weight[i1][i2][i3], d_preact[i4][i5][i6] * p_output[i4][i5 * 4 + i2][i6 * 4 + i3] / d);
# 	}
# }
#
# // Backpropagation: Compute bias gradients for the subsampling layer (s1)
# __global__ void bp_bias_s1(float bias[1], float d_preact[6][6][6])
# {
# 	const int pos = blockIdx.x * blockDim.x + threadIdx.x;
# 	const int size = blockDim.x * gridDim.x;
#
# 	const int N = 6 * 6 * 6;
# 	const float d = pow(6.0f, 3.0f); // Normalization factor
#
# 	// Update bias with gradients
# 	for (int n = N * pos / size; n < N * (pos + 1) / size; ++n) {
# 		int idx = n;
# 		const int i1 = ((idx /= 1) % 6);
# 		const int i2 = ((idx /= 6) % 6);
# 		const int i3 = ((idx /= 6) % 6);
#
# 		atomicAdd(&bias[0], dt * d_preact[i1][i2][i3] / d);
# 	}
# }
#
# // Backpropagation: Propagate output error for the convolutional layer (c1)
# __global__ void bp_output_c1(float d_output[6][24][24], float n_weight[1][4][4], float nd_preact[6][6][6])
# {
# 	const int pos = blockIdx.x * blockDim.x + threadIdx.x;
# 	const int size = blockDim.x * gridDim.x;
#
# 	const int N = 1 * 4 * 4 * 6 * 6 * 6;
#
# 	// Propagate error backward
# 	for (int n = N * pos / size; n < N * (pos + 1) / size; ++n) {
# 		int idx = n;
# 		const int i1 = ((idx /= 1) % 1);
# 		const int i2 = ((idx /= 1) % 4);
# 		const int i3 = ((idx /= 4) % 4);
# 		const int i4 = ((idx /= 4) % 6);
# 		const int i5 = ((idx /= 6) % 6);
# 		const int i6 = ((idx /= 6) % 6);
#
# 		atomicAdd(&d_output[i4][i5 * 4 + i2][i6 * 4 + i3], n_weight[i1][i2][i3] * nd_preact[i4][i5][i6]);
# 	}
# }
#
# // Backpropagation: Compute preactivation gradients for the convolutional layer (c1)
# __global__ void bp_preact_c1(float d_preact[6][24][24], float d_output[6][24][24], float preact[6][24][24])
# {
# 	const int pos = blockIdx.x * blockDim.x + threadIdx.x;
# 	const int size = blockDim.x * gridDim.x;
#
# 	const int N = 6 * 24 * 24;
#
# 	// Compute gradient of preactivation
# 	for (int n = N * pos / size; n < N * (pos + 1) / size; ++n) {
# 		int idx = n;
# 		const int i1 = ((idx /= 1) % 6);
# 		const int i2 = ((idx /= 6) % 24);
# 		const int i3 = ((idx /= 24) % 24);
#
# 		const float o = step_function(preact[i1][i2][i3]);
#
# 		d_preact[i1][i2][i3] = d_output[i1][i2][i3] * o * (1 - o); // Sigmoid derivative
# 	}
# }
#
# // Backpropagation: Compute weight gradients for the convolutional layer (c1)
# __global__ void bp_weight_c1(float d_weight[6][5][5], float d_preact[6][24][24], float p_output[28][28])
# {
# 	const int pos = blockIdx.x * blockDim.x + threadIdx.x;
# 	const int size = blockDim.x * gridDim.x;
#
# 	const int N = 6 * 5 * 5 * 24 * 24;
# 	const float d = pow(24.0f, 2.0f); // Normalization factor
#
# 	// Compute weight gradients
# 	for (int n = N * pos / size; n < N * (pos + 1) / size; ++n) {
# 		int idx = n;
# 		const int i1 = ((idx /= 1) % 6);
# 		const int i2 = ((idx /= 6) % 5);
# 		const int i3 = ((idx /= 5) % 5);
# 		const int i4 = ((idx /= 5) % 24);
# 		const int i5 = ((idx /= 24) % 24);
#
# 		atomicAdd(&d_weight[i1][i2][i3], d_preact[i1][i4][i5] * p_output[i4 + i2][i5 + i3] / d);
# 	}
# }
#
# // Backpropagation: Compute bias gradients for the convolutional layer (c1)
# __global__ void bp_bias_c1(float bias[6], float d_preact[6][24][24])
# {
# 	const int pos = blockIdx.x * blockDim.x + threadIdx.x;
# 	const int size = blockDim.x * gridDim.x;
#
# 	const int N = 6 * 24 * 24;
# 	const float d = pow(24.0f, 2.0f); // Normalization factor
#
# 	// Update bias with gradients
# 	for (int n = N * pos / size; n < N * (pos + 1) / size; ++n) {
# 		int idx = n;
# 		const int i1 = ((idx /= 1) % 6);
# 		const int i2 = ((idx /= 6) % 24);
# 		const int i3 = ((idx /= 24) % 24);
#
# 		atomicAdd(&bias[i1], dt * d_preact[i1][i2][i3] / d);
# 	}
# }
# Out:
# Overwriting layer.cu

# %% [markdown]
# ### MNIST Dataset Loader Header File
#
# **Description:**
# This cell writes the `mnist.h` file, which provides functions and structures for loading the MNIST dataset. It includes methods for reading MNIST image and label files and converting them into a usable format for training and testing a Convolutional Neural Network (CNN).
#
# ---
#
# **Key Components:**
#
# 1. **Data Structure:**
#    - Defines the `mnist_data` structure to hold:
#      - **`data[28][28]`:** 28x28 pixel grayscale image data.
#      - **`label`:** The corresponding label (0-9) for the image.
#
# 2. **Macro Definitions:**
#    - **`USE_MNIST_LOADER`:** Activates the MNIST loader functionality.
#    - **`MNIST_DOUBLE`:** Allows image data to be stored as normalized double values (0.0 to 1.0).
#
# 3. **Helper Function:**
#    - **`mnist_bin_to_int`:** Converts raw binary data to unsigned integers (used for reading headers of MNIST files).
#
# 4. **MNIST Dataset Loader:**
#    - **`mnist_load`:** Reads image and label files, validates the data, and loads the dataset into memory.
#      - Validates that the number of images matches the number of labels.
#      - Normalizes image data if `MNIST_DOUBLE` is enabled.
#
# 5. **File Validation:**
#    - Ensures that the input files are valid MNIST datasets by checking:
#      - Magic numbers (`2051` for images, `2049` for labels).
#      - Image dimensions (28x28 pixels).
#
# 6. **Error Handling:**
#    - Provides error codes for invalid or mismatched files:
#      - `-1`: Missing files.
#      - `-2`: Invalid image file.
#      - `-3`: Invalid label file.
#      - `-4`: Mismatch in the number of images and labels.
#
# 7. **C++ Compatibility:**
#    - Includes `extern "C"` for compatibility with C++ compilers.

# %%
# %%writefile mnist.h
#
# #ifndef __MNIST_H__
# #define __MNIST_H__
#
# // Activate MNIST loader functionality
# #ifdef USE_MNIST_LOADER
#
# #ifdef __cplusplus
# extern "C" {
# #endif
#
# /*
#  * Make mnist_load function static if MNIST_STATIC is defined.
#  * Ensures the function is scoped only to the file if the macro is active.
#  */
# #ifdef MNIST_STATIC
# #define _STATIC static
# #else
# #define _STATIC
# #endif
#
# /*
#  * Define the data type for MNIST images.
#  * If MNIST_DOUBLE is defined, the data will be loaded as double.
#  * Otherwise, it will be loaded as unsigned char.
#  */
# #ifdef MNIST_DOUBLE
# #define MNIST_DATA_TYPE double
# #else
# #define MNIST_DATA_TYPE unsigned char
# #endif
#
# // Structure representing an MNIST data sample
# typedef struct mnist_data {
# 	MNIST_DATA_TYPE data[28][28]; /* 28x28 pixel image data */
# 	unsigned int label;           /* Label for the image (0 to 9) */
# } mnist_data;
#
# // Function prototype declaration for the MNIST data loader
# #ifdef MNIST_HDR_ONLY
#
# _STATIC int mnist_load(
# 	const char *image_filename,  // Path to the MNIST image file
# 	const char *label_filename,  // Path to the MNIST label file
# 	mnist_data **data,           // Pointer to store loaded MNIST data
# 	unsigned int *count          // Pointer to store the number of samples
# );
#
# #else
#
# #include <stdio.h>
# #include <stdlib.h>
# #include <string.h>
#
# /*
#  * Converts 4 bytes of data (big-endian) to an unsigned integer.
#  * Used to read integer values (e.g., header fields) from the MNIST files.
#  */
# static unsigned int mnist_bin_to_int(char *v)
# {
# 	int i;
# 	unsigned int ret = 0;
#
# 	for (i = 0; i < 4; ++i) {
# 		ret <<= 8;             // Shift by 8 bits to the left
# 		ret |= (unsigned char)v[i]; // Read byte and combine
# 	}
#
# 	return ret;
# }
#
# /*
#  * Loads MNIST data (images and labels) from files.
#  * Returns 0 on success and specific error codes for various failure scenarios.
#  */
# _STATIC int mnist_load(
# 	const char *image_filename,  // MNIST image file path
# 	const char *label_filename,  // MNIST label file path
# 	mnist_data **data,           // Pointer to store the dataset
# 	unsigned int *count          // Pointer to store the number of samples
# )
# {
# 	int return_code = 0; // Return code to indicate success or failure
# 	int i;
# 	char tmp[4]; // Temporary buffer for reading header data
#
# 	unsigned int image_cnt, label_cnt; // Number of images and labels
# 	unsigned int image_dim[2];         // Image dimensions (28x28)
#
# 	FILE *ifp = fopen(image_filename, "rb"); // Open image file in binary mode
# 	FILE *lfp = fopen(label_filename, "rb"); // Open label file in binary mode
#
# 	if (!ifp || !lfp) {
# 		return_code = -1; /* Error: Files not found */
# 		goto cleanup;
# 	}
#
# 	// Verify image file magic number (2051)
# 	fread(tmp, 1, 4, ifp);
# 	if (mnist_bin_to_int(tmp) != 2051) {
# 		return_code = -2; /* Error: Not a valid image file */
# 		goto cleanup;
# 	}
#
# 	// Verify label file magic number (2049)
# 	fread(tmp, 1, 4, lfp);
# 	if (mnist_bin_to_int(tmp) != 2049) {
# 		return_code = -3; /* Error: Not a valid label file */
# 		goto cleanup;
# 	}
#
# 	// Read number of images and labels
# 	fread(tmp, 1, 4, ifp);
# 	image_cnt = mnist_bin_to_int(tmp);
#
# 	fread(tmp, 1, 4, lfp);
# 	label_cnt = mnist_bin_to_int(tmp);
#
# 	// Check if the number of images matches the number of labels
# 	if (image_cnt != label_cnt) {
# 		return_code = -4; /* Error: Mismatch between images and labels */
# 		goto cleanup;
# 	}
#
# 	// Read image dimensions (should be 28x28)
# 	for (i = 0; i < 2; ++i) {
# 		fread(tmp, 1, 4, ifp);
# 		image_dim[i] = mnist_bin_to_int(tmp);
# 	}
#
# 	if (image_dim[0] != 28 || image_dim[1] != 28) {
# 		return_code = -2; /* Error: Invalid image dimensions */
# 		goto cleanup;
# 	}
#
# 	// Allocate memory for storing MNIST data
# 	*count = image_cnt; // Number of samples
# 	*data = (mnist_data *)malloc(sizeof(mnist_data) * image_cnt);
#
# 	// Load each sample
# 	for (i = 0; i < image_cnt; ++i) {
# 		int j;
# 		unsigned char read_data[28 * 28]; // Temporary buffer for image data
# 		mnist_data *d = &(*data)[i];      // Pointer to the current sample
#
# 		// Read image data
# 		fread(read_data, 1, 28*28, ifp);
#
# #ifdef MNIST_DOUBLE
# 		// Normalize image data to the range [0.0, 1.0] (if using double)
# 		for (j = 0; j < 28*28; ++j) {
# 			d->data[j/28][j%28] = read_data[j] / 255.0;
# 		}
# #else
# 		// Copy raw image data directly
# 		memcpy(d->data, read_data, 28*28);
# #endif
#
# 		// Read label
# 		fread(tmp, 1, 1, lfp);
# 		d->label = tmp[0];
# 	}
#
# cleanup:
# 	// Close the files
# 	if (ifp) fclose(ifp);
# 	if (lfp) fclose(lfp);
#
# 	return return_code; // Return status
# }
#
# #endif /* MNIST_HDR_ONLY */
#
# #ifdef __cplusplus
# }
# #endif
#
# #endif /* USE_MNIST_LOADER */
# #endif /* __MNIST_H__ */
# Out:
# Writing mnist.h

# %% [markdown]
# ### Implement Main Program for CNN Training and Testing
#
# **Description:**
# This cell writes the `main.cu` file, which is the main program for training and testing a Convolutional Neural Network (CNN) using the MNIST dataset. It includes data loading, forward and backward propagation, and accuracy evaluation.
#
# ---
#
# **Key Components:**
#
# 1. **Data Loading:**
#    - **`loaddata`:** Loads the MNIST dataset, including training and test sets, from specified files. It uses the `mnist_load` function to populate `train_set` and `test_set`.
#
# 2. **Layer Initialization:**
#    - Defines CNN layers:
#      - **Input Layer (`l_input`):** Processes input data (28x28 images).
#      - **Convolutional Layer 1 (`l_c1`):** First convolutional layer with 6 filters.
#      - **Subsampling Layer 1 (`l_s1`):** First pooling layer.
#      - **Fully Connected Layer (`l_f`):** Final classification layer for 10 classes.
#
# 3. **Forward Propagation:**
#    - **`forward_pass`:** Performs forward propagation through all layers.
#      - Computes pre-activation, applies activation functions, and produces output.
#
# 4. **Backward Propagation:**
#    - **`back_pass`:** Computes gradients and updates weights and biases using backpropagation.
#
# 5. **Learning Process:**
#    - **`learn`:** Trains the CNN on the training dataset.
#      - Loops over training samples.
#      - Measures error and adjusts weights until convergence or a maximum number of iterations.
#
# 6. **Classification:**
#    - **`classify`:** Predicts the label of a given input image using the trained model.
#
# 7. **Testing and Accuracy Evaluation:**
#    - **`test`:** Evaluates the CNN on the test dataset.
#      - Compares predicted labels with actual labels.
#      - Outputs:
#        - Predicted and actual labels for each sample.
#        - Training and test dataset sizes.
#        - Final error rate and model accuracy.
#
# 8. **CUDA Initialization:**
#    - **`cuInit`:** Initializes the CUDA driver for GPU operations.
#
# 9. **Performance Metrics:**
#    - Measures computation time for forward and backward passes.
#    - Displays the overall time taken for training.
#
# 10. **Program Workflow:**
#     - **Main Function:**
#       1. Initializes CUDA.
#       2. Loads MNIST data.
#       3. Trains the CNN using the `learn` function.
#       4. Tests the CNN and prints accuracy and error rate.

# %%
# %%writefile main.cu
#
# // Enable MNIST loader functionality and double precision
# #define USE_MNIST_LOADER
# #define MNIST_DOUBLE
# #include "mnist.h"
# #include "layer.h"
#
# #include <cuda.h>
# #include <cstdio>
# #include <time.h>
#
# // Pointers for training and testing datasets
# static mnist_data *train_set, *test_set;
# static unsigned int train_cnt, test_cnt;
#
# // Define CNN layers
# static Layer l_input = Layer(0, 0, 28*28);      // Input layer
# static Layer l_c1 = Layer(5*5, 6, 24*24*6);    // First convolutional layer
# static Layer l_s1 = Layer(4*4, 1, 6*6*6);      // Subsampling layer
# static Layer l_f = Layer(6*6*6, 10, 10);       // Fully connected layer
#
# // Function declarations
# static void learn();
# static unsigned int classify(double data[28][28]);
# static void test();
# static double forward_pass(double data[28][28]);
# static double back_pass();
#
# // Load MNIST dataset into memory
# static inline void loaddata()
# {
# 	mnist_load("data/MNIST/raw/train-images-idx3-ubyte", "data/MNIST/raw/train-labels-idx1-ubyte",
# 		&train_set, &train_cnt);
# 	mnist_load("data/MNIST/raw/t10k-images-idx3-ubyte", "data/MNIST/raw/t10k-labels-idx1-ubyte",
# 		&test_set, &test_cnt);
# }
#
# int main(int argc, const char **argv)
# {
# 	// Seed random number generator
# 	srand(time(NULL));
#
# 	// Initialize CUDA
# 	CUresult err = cuInit(0);
# 	if (err != CUDA_SUCCESS) {
# 		fprintf(stderr, "CUDA initialization failed with error code - %d\n", err);
# 		return 1;
# 	}
#
# 	// Load dataset and train/test the model
# 	loaddata();
# 	learn();
# 	test();
#
# 	return 0;
# }
#
# // Perform forward propagation for one data sample
# static double forward_pass(double data[28][28])
# {
# 	float input[28][28];
#
# 	// Convert data to float for processing
# 	for (int i = 0; i < 28; ++i) {
# 		for (int j = 0; j < 28; ++j) {
# 			input[i][j] = data[i][j];
# 		}
# 	}
#
# 	// Clear outputs and preactivations for all layers
# 	l_input.clear();
# 	l_c1.clear();
# 	l_s1.clear();
# 	l_f.clear();
#
# 	// Record time for forward propagation
# 	clock_t start, end;
# 	start = clock();
#
# 	// Set input layer output
# 	l_input.setOutput((float *)input);
#
# 	// Forward propagation through each layer
# 	fp_preact_c1<<<64, 64>>>((float (*)[28])l_input.output, (float (*)[24][24])l_c1.preact, (float (*)[5][5])l_c1.weight);
# 	fp_bias_c1<<<64, 64>>>((float (*)[24][24])l_c1.preact, l_c1.bias);
# 	apply_step_function<<<64, 64>>>(l_c1.preact, l_c1.output, l_c1.O);
#
# 	fp_preact_s1<<<64, 64>>>((float (*)[24][24])l_c1.output, (float (*)[6][6])l_s1.preact, (float (*)[4][4])l_s1.weight);
# 	fp_bias_s1<<<64, 64>>>((float (*)[6][6])l_s1.preact, l_s1.bias);
# 	apply_step_function<<<64, 64>>>(l_s1.preact, l_s1.output, l_s1.O);
#
# 	fp_preact_f<<<64, 64>>>((float (*)[6][6])l_s1.output, l_f.preact, (float (*)[6][6][6])l_f.weight);
# 	fp_bias_f<<<64, 64>>>(l_f.preact, l_f.bias);
# 	apply_step_function<<<64, 64>>>(l_f.preact, l_f.output, l_f.O);
#
# 	// Calculate time taken for forward pass
# 	end = clock();
# 	return ((double) (end - start)) / CLOCKS_PER_SEC;
# }
#
# // Perform backward propagation and update weights
# static double back_pass()
# {
# 	clock_t start, end;
# 	start = clock();
#
# 	// Compute gradients and update weights for all layers
# 	bp_weight_f<<<64, 64>>>((float (*)[6][6][6])l_f.d_weight, l_f.d_preact, (float (*)[6][6])l_s1.output);
# 	bp_bias_f<<<64, 64>>>(l_f.bias, l_f.d_preact);
#
# 	bp_output_s1<<<64, 64>>>((float (*)[6][6])l_s1.d_output, (float (*)[6][6][6])l_f.weight, l_f.d_preact);
# 	bp_preact_s1<<<64, 64>>>((float (*)[6][6])l_s1.d_preact, (float (*)[6][6])l_s1.d_output, (float (*)[6][6])l_s1.preact);
# 	bp_weight_s1<<<64, 64>>>((float (*)[4][4])l_s1.d_weight, (float (*)[6][6])l_s1.d_preact, (float (*)[24][24])l_c1.output);
# 	bp_bias_s1<<<64, 64>>>(l_s1.bias, (float (*)[6][6])l_s1.d_preact);
#
# 	bp_output_c1<<<64, 64>>>((float (*)[24][24])l_c1.d_output, (float (*)[4][4])l_s1.weight, (float (*)[6][6])l_s1.d_preact);
# 	bp_preact_c1<<<64, 64>>>((float (*)[24][24])l_c1.d_preact, (float (*)[24][24])l_c1.d_output, (float (*)[24][24])l_c1.preact);
# 	bp_weight_c1<<<64, 64>>>((float (*)[5][5])l_c1.d_weight, (float (*)[24][24])l_c1.d_preact, (float (*)[28])l_input.output);
# 	bp_bias_c1<<<64, 64>>>(l_c1.bias, (float (*)[24][24])l_c1.d_preact);
#
# 	// Update weights for all layers
# 	apply_grad<<<64, 64>>>(l_f.weight, l_f.d_weight, l_f.M * l_f.N);
# 	apply_grad<<<64, 64>>>(l_s1.weight, l_s1.d_weight, l_s1.M * l_s1.N);
# 	apply_grad<<<64, 64>>>(l_c1.weight, l_c1.d_weight, l_c1.M * l_c1.N);
#
# 	end = clock();
# 	return ((double) (end - start)) / CLOCKS_PER_SEC;
# }
#
# // Training the CNN
# static void learn()
# {
# 	static cublasHandle_t blas;
# 	cublasCreate(&blas);
#
# 	float err;
# 	int iter = 50; // Maximum number of iterations
# 	int iter_count = 1;
# 	double time_taken = 0.0;
#
# 	fprintf(stdout ,"Learning...\n");
#
# 	while (iter < 0 || iter-- > 0) {
# 		err = 0.0f;
#
# 		// Process each training sample
# 		for (int i = 0; i < train_cnt; ++i) {
# 			float tmp_err;
#
# 			time_taken += forward_pass(train_set[i].data);
#
# 			// Clear gradients for backward pass
# 			l_f.bp_clear();
# 			l_s1.bp_clear();
# 			l_c1.bp_clear();
#
# 			// Compute error for the current sample
# 			makeError<<<10, 1>>>(l_f.d_preact, l_f.output, train_set[i].label, 10);
# 			cublasSnrm2(blas, 10, l_f.d_preact, 1, &tmp_err);
# 			err += tmp_err;
#
# 			time_taken += back_pass();
# 		}
#
# 		err /= train_cnt; // Average error
# 		fprintf(stdout, "Iteration ---> %d, Error: %e, Time on GPU: %lf\n", iter_count, err, time_taken);
#
# 		if (err < threshold) { // Check convergence
# 			fprintf(stdout, "Training Complete, Error less than Threshold\n\n");
# 			break;
# 		}
#
# 		iter_count++;
# 	}
#
# 	fprintf(stdout, "\n Time - %lf\n", time_taken);
# }
#
# // Predict the label of a single sample
# static unsigned int classify(double data[28][28])
# {
# 	float res[10]; // Output probabilities
#
# 	forward_pass(data);
#
# 	unsigned int max = 0;
#
# 	// Retrieve results from GPU
# 	cudaMemcpy(res, l_f.output, sizeof(float) * 10, cudaMemcpyDeviceToHost);
#
# 	// Find the class with the highest probability
# 	for (int i = 1; i < 10; ++i) {
# 		if (res[max] < res[i]) {
# 			max = i;
# 		}
# 	}
#
# 	return max;
# }
#
# // Evaluate model on the test dataset
# static void test()
# {
# 	int error = 0;
#
# 	printf("------------------------------------\n");
# 	for (int i = 0; i < test_cnt; ++i) {
# 		printf("Sample Test Data %d: Predicted: %d, Actual: %d\n", i + 1, classify(test_set[i].data), test_set[i].label);
# 		if (classify(test_set[i].data) != test_set[i].label) {
# 			++error;
# 		}
# 	}
#
# 	// Print summary
# 	fprintf(stdout, "\n========= Summary =========\n");
# 	fprintf(stdout, "Training Set Size: %u\n", train_cnt);
# 	fprintf(stdout, "Test Set Size: %u\n", test_cnt);
# 	fprintf(stdout, "Final Error Rate: %.2lf%%\n", double(error) / double(test_cnt) * 100.0);
# 	double accuracy = 100.0 - (double(error) / double(test_cnt) * 100.0);
# 	fprintf(stdout, "Model Accuracy: %.2lf%%\n", accuracy);
# 	fprintf(stdout, "===========================\n");
# }
# Out:
# Writing main.cu

# %% [markdown]
# ### Build and Run CNN with Makefile
#
# **Description:**
# This cell writes the `Makefile`, which automates the build process for compiling and running the CUDA-based Convolutional Neural Network (CNN). It defines the commands to compile, execute, and clean up the program.
#
# ---
#
# **Key Components:**
#
# 1. **Architecture Selection:**
#    - **`ARCH`:** Specifies the GPU architecture for CUDA compilation.
#      - In this case, it is set to `sm_70`, which targets NVIDIA GPUs with compute capability 7.0 (e.g., Volta architecture).
#
# 2. **Build Command:**
#    - **`all`:** The default target for compiling the CNN program.
#      - Compiles all `.cu` files using `nvcc` (NVIDIA CUDA Compiler).
#      - Links the `cuda` and `cublas` libraries required for CUDA operations.
#      - Produces the executable named `CNN`.
#
# 3. **Run Command:**
#    - **`run`:** Executes the compiled CNN program.
#
# 4. **Clean Command:**
#    - **`clean`:** Removes the `CNN` executable to clean up the build environment.

# %%
# %%writefile Makefile
#
# ARCH = -arch=sm_70
#
# all:
# 	nvcc -lcuda -lcublas *.cu -o CNN $(ARCH)
#
# run:
# 	./CNN
#
# clean:
# 	rm -f CNN
# Out:
# Writing Makefile

# %% [markdown]
# ### Build the CNN Program with Makefile
#
# **Description:**
# This cell runs the `make` command to compile the Convolutional Neural Network (CNN) program written in CUDA using the instructions provided in the `Makefile`. This step is necessary to generate an executable file for the program.
#
# ---
#
# **Steps Executed:**
#
# 1. **Invokes the `all` Target in the Makefile:**
#    - Compiles all `.cu` files using `nvcc` (NVIDIA CUDA Compiler).
#    - Links necessary libraries, such as `cuda` and `cublas`.
#    - Generates an executable file named `CNN`.
#
# 2. **Checks GPU Architecture:**
#    - The `ARCH` variable in the Makefile specifies the GPU architecture (`sm_70` for Volta architecture).
#
# 3. **Outputs Build Logs:**
#    - Displays the progress of the compilation, including errors or warnings.
#
# ---
#
# **Expected Outcome:**
# - If successful:
#   - The executable file `CNN` is created in the current directory.
#   - No errors or warnings are displayed.
#
# - If there are errors:
#   - The output will highlight issues such as missing dependencies, syntax errors, or unsupported architectures.

# %%
# !make
# Out:
# nvcc -lcuda -lcublas *.cu -o CNN -arch=sm_70

# %% [markdown]
# ### Run the Compiled CNN Program
#
# **Description:**
# This cell executes the `make run` command to run the CNN program built using the `make` command. The `Makefile` includes a `run` target, which runs the compiled executable `CNN`.
#
# ---
#
# **Steps Executed:**
#
# 1. **Execute the CNN Program:**
#    - The `make run` command invokes the `./CNN` executable generated during the `make` process.
#
# 2. **Program Workflow:**
#    - Loads the MNIST dataset.
#    - Trains the Convolutional Neural Network (CNN) using the training dataset.
#    - Evaluates the trained model on the test dataset.
#    - Outputs:
#      - Training progress (errors and time taken for each iteration).
#      - Predicted and actual labels for test data.
#      - Model accuracy and error rate.
#
# 3. **Monitor Output:**
#    - Watch for the program's logs in the output to confirm successful execution and check for accuracy metrics.
#
# ---
#
# **Expected Outcome:**
# - If the program executes successfully, it will display:
#   - Training logs, including error rates and time metrics.
#   - Testing results, including a summary of accuracy and error rates.
#
# - If there are issues:
#   - The output will display error messages indicating the problem, such as missing files or runtime errors.

# %%
# !make run
# Out:
# Streaming output truncated to the last 5000 lines.
# Sample Test Data 5008: Predicted: 6, Actual: 6
# Sample Test Data 5009: Predicted: 0, Actual: 0
# Sample Test Data 5010: Predicted: 9, Actual: 9
# Sample Test Data 5011: Predicted: 6, Actual: 6
# Sample Test Data 5012: Predicted: 8, Actual: 8
# Sample Test Data 5013: Predicted: 6, Actual: 6
# Sample Test Data 5014: Predicted: 1, Actual: 1
# Sample Test Data 5015: Predicted: 1, Actual: 1
# Sample Test Data 5016: Predicted: 9, Actual: 9
# Sample Test Data 5017: Predicted: 8, Actual: 8
# Sample Test Data 5018: Predicted: 9, Actual: 9
# Sample Test Data 5019: Predicted: 2, Actual: 2
# Sample Test Data 5020: Predicted: 3, Actual: 3
# Sample Test Data 5021: Predicted: 5, Actual: 5
# Sample Test Data 5022: Predicted: 5, Actual: 5
# Sample Test Data 5023: Predicted: 9, Actual: 9
# Sample Test Data 5024: Predicted: 4, Actual: 4
# Sample Test Data 5025: Predicted: 2, Actual: 2
# Sample Test Data 5026: Predicted: 1, Actual: 1
# Sample Test Data 5027: Predicted: 9, Actual: 9
# Sample Test Data 5028: Predicted: 4, Actual: 4
# Sample Test Data 5029: Predicted: 3, Actual: 3
# Sample Test Data 5030: Predicted: 9, Actual: 9
# Sample Test Data 5031: Predicted: 6, Actual: 6
# Sample Test Data 5032: Predicted: 0, Actual: 0
# Sample Test Data 5033: Predicted: 4, Actual: 4
# Sample Test Data 5034: Predicted: 0, Actual: 0
# Sample Test Data 5035: Predicted: 6, Actual: 6
# Sample Test Data 5036: Predicted: 0, Actual: 0
# Sample Test Data 5037: Predicted: 1, Actual: 1
# Sample Test Data 5038: Predicted: 2, Actual: 2
# Sample Test Data 5039: Predicted: 3, Actual: 3
# Sample Test Data 5040: Predicted: 4, Actual: 4
# Sample Test Data 5041: Predicted: 7, Actual: 7
# Sample Test Data 5042: Predicted: 8, Actual: 8
# Sample Test Data 5043: Predicted: 9, Actual: 9
# Sample Test Data 5044: Predicted: 0, Actual: 0
# Sample Test Data 5045: Predicted: 1, Actual: 1
# Sample Test Data 5046: Predicted: 2, Actual: 2
# Sample Test Data 5047: Predicted: 3, Actual: 3
# Sample Test Data 5048: Predicted: 4, Actual: 4
# Sample Test Data 5049: Predicted: 7, Actual: 7
# Sample Test Data 5050: Predicted: 8, Actual: 8
# Sample Test Data 5051: Predicted: 9, Actual: 9
# Sample Test Data 5052: Predicted: 0, Actual: 0
# Sample Test Data 5053: Predicted: 1, Actual: 1
# Sample Test Data 5054: Predicted: 2, Actual: 2
# Sample Test Data 5055: Predicted: 3, Actual: 3
# Sample Test Data 5056: Predicted: 4, Actual: 4
# Sample Test Data 5057: Predicted: 5, Actual: 5
# Sample Test Data 5058: Predicted: 6, Actual: 6
# Sample Test Data 5059: Predicted: 7, Actual: 7
# Sample Test Data 5060: Predicted: 8, Actual: 8
# Sample Test Data 5061: Predicted: 9, Actual: 9
# Sample Test Data 5062: Predicted: 8, Actual: 8
# Sample Test Data 5063: Predicted: 3, Actual: 3
# Sample Test Data 5064: Predicted: 4, Actual: 4
# Sample Test Data 5065: Predicted: 7, Actual: 7
# Sample Test Data 5066: Predicted: 8, Actual: 8
# Sample Test Data 5067: Predicted: 6, Actual: 6
# Sample Test Data 5068: Predicted: 3, Actual: 3
# Sample Test Data 5069: Predicted: 4, Actual: 4
# Sample Test Data 5070: Predicted: 0, Actual: 0
# Sample Test Data 5071: Predicted: 9, Actual: 9
# Sample Test Data 5072: Predicted: 7, Actual: 7
# Sample Test Data 5073: Predicted: 1, Actual: 1
# Sample Test Data 5074: Predicted: 9, Actual: 9
# Sample Test Data 5075: Predicted: 3, Actual: 3
# Sample Test Data 5076: Predicted: 8, Actual: 8
# Sample Test Data 5077: Predicted: 4, Actual: 4
# Sample Test Data 5078: Predicted: 7, Actual: 7
# Sample Test Data 5079: Predicted: 3, Actual: 3
# Sample Test Data 5080: Predicted: 0, Actual: 0
# Sample Test Data 5081: Predicted: 9, Actual: 9
# Sample Test Data 5082: Predicted: 1, Actual: 1
# Sample Test Data 5083: Predicted: 4, Actual: 4
# Sample Test Data 5084: Predicted: 5, Actual: 5
# Sample Test Data 5085: Predicted: 4, Actual: 4
# Sample Test Data 5086: Predicted: 6, Actual: 6
# Sample Test Data 5087: Predicted: 2, Actual: 2
# Sample Test Data 5088: Predicted: 0, Actual: 0
# Sample Test Data 5089: Predicted: 6, Actual: 6
# Sample Test Data 5090: Predicted: 2, Actual: 2
# Sample Test Data 5091: Predicted: 1, Actual: 1
# Sample Test Data 5092: Predicted: 1, Actual: 1
# Sample Test Data 5093: Predicted: 1, Actual: 1
# Sample Test Data 5094: Predicted: 1, Actual: 1
# Sample Test Data 5095: Predicted: 7, Actual: 7
# Sample Test Data 5096: Predicted: 2, Actual: 2
# Sample Test Data 5097: Predicted: 4, Actual: 4
# Sample Test Data 5098: Predicted: 7, Actual: 7
# Sample Test Data 5099: Predicted: 5, Actual: 5
# Sample Test Data 5100: Predicted: 2, Actual: 2
# Sample Test Data 5101: Predicted: 9, Actual: 9
# Sample Test Data 5102: Predicted: 4, Actual: 4
# Sample Test Data 5103: Predicted: 5, Actual: 5
# Sample Test Data 5104: Predicted: 8, Actual: 8
# Sample Test Data 5105: Predicted: 4, Actual: 4
# Sample Test Data 5106: Predicted: 2, Actual: 2
# Sample Test Data 5107: Predicted: 9, Actual: 9
# Sample Test Data 5108: Predicted: 7, Actual: 7
# Sample Test Data 5109: Predicted: 0, Actual: 0
# Sample Test Data 5110: Predicted: 0, Actual: 0
# Sample Test Data 5111: Predicted: 7, Actual: 7
# Sample Test Data 5112: Predicted: 5, Actual: 5
# Sample Test Data 5113: Predicted: 1, Actual: 1
# Sample Test Data 5114: Predicted: 1, Actual: 1
# Sample Test Data 5115: Predicted: 7, Actual: 7
# Sample Test Data 5116: Predicted: 6, Actual: 6
# Sample Test Data 5117: Predicted: 6, Actual: 6
# Sample Test Data 5118: Predicted: 6, Actual: 6
# Sample Test Data 5119: Predicted: 8, Actual: 8
# Sample Test Data 5120: Predicted: 2, Actual: 2
# Sample Test Data 5121: Predicted: 2, Actual: 2
# Sample Test Data 5122: Predicted: 7, Actual: 7
# Sample Test Data 5123: Predicted: 7, Actual: 7
# Sample Test Data 5124: Predicted: 4, Actual: 4
# Sample Test Data 5125: Predicted: 0, Actual: 0
# Sample Test Data 5126: Predicted: 2, Actual: 2
# Sample Test Data 5127: Predicted: 4, Actual: 4
# Sample Test Data 5128: Predicted: 2, Actual: 2
# Sample Test Data 5129: Predicted: 1, Actual: 1
# Sample Test Data 5130: Predicted: 8, Actual: 8
# Sample Test Data 5131: Predicted: 9, Actual: 9
# Sample Test Data 5132: Predicted: 6, Actual: 6
# Sample Test Data 5133: Predicted: 1, Actual: 1
# Sample Test Data 5134: Predicted: 0, Actual: 0
# Sample Test Data 5135: Predicted: 5, Actual: 5
# Sample Test Data 5136: Predicted: 9, Actual: 9
# Sample Test Data 5137: Predicted: 6, Actual: 6
# Sample Test Data 5138: Predicted: 9, Actual: 9
# Sample Test Data 5139: Predicted: 8, Actual: 8
# Sample Test Data 5140: Predicted: 0, Actual: 0
# Sample Test Data 5141: Predicted: 3, Actual: 3
# Sample Test Data 5142: Predicted: 0, Actual: 0
# Sample Test Data 5143: Predicted: 8, Actual: 8
# Sample Test Data 5144: Predicted: 3, Actual: 3
# Sample Test Data 5145: Predicted: 9, Actual: 9
# Sample Test Data 5146: Predicted: 6, Actual: 6
# Sample Test Data 5147: Predicted: 3, Actual: 3
# Sample Test Data 5148: Predicted: 0, Actual: 0
# Sample Test Data 5149: Predicted: 1, Actual: 1
# Sample Test Data 5150: Predicted: 2, Actual: 2
# Sample Test Data 5151: Predicted: 3, Actual: 3
# Sample Test Data 5152: Predicted: 4, Actual: 4
# Sample Test Data 5153: Predicted: 5, Actual: 5
# Sample Test Data 5154: Predicted: 6, Actual: 6
# Sample Test Data 5155: Predicted: 7, Actual: 7
# Sample Test Data 5156: Predicted: 0, Actual: 0
# Sample Test Data 5157: Predicted: 1, Actual: 1
# Sample Test Data 5158: Predicted: 2, Actual: 2
# Sample Test Data 5159: Predicted: 3, Actual: 3
# Sample Test Data 5160: Predicted: 4, Actual: 4
# Sample Test Data 5161: Predicted: 5, Actual: 5
# Sample Test Data 5162: Predicted: 6, Actual: 6
# Sample Test Data 5163: Predicted: 7, Actual: 7
# Sample Test Data 5164: Predicted: 8, Actual: 8
# Sample Test Data 5165: Predicted: 9, Actual: 9
# Sample Test Data 5166: Predicted: 0, Actual: 0
# Sample Test Data 5167: Predicted: 1, Actual: 1
# Sample Test Data 5168: Predicted: 2, Actual: 2
# Sample Test Data 5169: Predicted: 3, Actual: 3
# Sample Test Data 5170: Predicted: 4, Actual: 4
# Sample Test Data 5171: Predicted: 5, Actual: 5
# Sample Test Data 5172: Predicted: 6, Actual: 6
# Sample Test Data 5173: Predicted: 7, Actual: 7
# Sample Test Data 5174: Predicted: 8, Actual: 8
# Sample Test Data 5175: Predicted: 5, Actual: 5
# Sample Test Data 5176: Predicted: 4, Actual: 4
# Sample Test Data 5177: Predicted: 8, Actual: 8
# Sample Test Data 5178: Predicted: 7, Actual: 7
# Sample Test Data 5179: Predicted: 4, Actual: 4
# Sample Test Data 5180: Predicted: 7, Actual: 7
# Sample Test Data 5181: Predicted: 7, Actual: 7
# Sample Test Data 5182: Predicted: 3, Actual: 3
# Sample Test Data 5183: Predicted: 9, Actual: 9
# Sample Test Data 5184: Predicted: 8, Actual: 8
# Sample Test Data 5185: Predicted: 8, Actual: 8
# Sample Test Data 5186: Predicted: 3, Actual: 3
# Sample Test Data 5187: Predicted: 1, Actual: 1
# Sample Test Data 5188: Predicted: 5, Actual: 5
# Sample Test Data 5189: Predicted: 8, Actual: 8
# Sample Test Data 5190: Predicted: 2, Actual: 2
# Sample Test Data 5191: Predicted: 7, Actual: 7
# Sample Test Data 5192: Predicted: 4, Actual: 4
# Sample Test Data 5193: Predicted: 2, Actual: 2
# Sample Test Data 5194: Predicted: 1, Actual: 1
# Sample Test Data 5195: Predicted: 5, Actual: 5
# Sample Test Data 5196: Predicted: 4, Actual: 4
# Sample Test Data 5197: Predicted: 5, Actual: 5
# Sample Test Data 5198: Predicted: 5, Actual: 5
# Sample Test Data 5199: Predicted: 8, Actual: 8
# Sample Test Data 5200: Predicted: 6, Actual: 6
# Sample Test Data 5201: Predicted: 4, Actual: 4
# Sample Test Data 5202: Predicted: 4, Actual: 4
# Sample Test Data 5203: Predicted: 4, Actual: 4
# Sample Test Data 5204: Predicted: 1, Actual: 1
# Sample Test Data 5205: Predicted: 8, Actual: 8
# Sample Test Data 5206: Predicted: 7, Actual: 7
# Sample Test Data 5207: Predicted: 5, Actual: 5
# Sample Test Data 5208: Predicted: 5, Actual: 5
# Sample Test Data 5209: Predicted: 1, Actual: 1
# Sample Test Data 5210: Predicted: 8, Actual: 8
# Sample Test Data 5211: Predicted: 9, Actual: 9
# Sample Test Data 5212: Predicted: 1, Actual: 1
# Sample Test Data 5213: Predicted: 3, Actual: 3
# Sample Test Data 5214: Predicted: 6, Actual: 6
# Sample Test Data 5215: Predicted: 3, Actual: 3
# Sample Test Data 5216: Predicted: 3, Actual: 3
# Sample Test Data 5217: Predicted: 2, Actual: 2
# Sample Test Data 5218: Predicted: 2, Actual: 2
# Sample Test Data 5219: Predicted: 6, Actual: 6
# Sample Test Data 5220: Predicted: 9, Actual: 9
# Sample Test Data 5221: Predicted: 9, Actual: 9
# Sample Test Data 5222: Predicted: 6, Actual: 6
# Sample Test Data 5223: Predicted: 5, Actual: 5
# Sample Test Data 5224: Predicted: 5, Actual: 5
# Sample Test Data 5225: Predicted: 3, Actual: 3
# Sample Test Data 5226: Predicted: 3, Actual: 3
# Sample Test Data 5227: Predicted: 8, Actual: 8
# Sample Test Data 5228: Predicted: 1, Actual: 1
# Sample Test Data 5229: Predicted: 6, Actual: 6
# Sample Test Data 5230: Predicted: 5, Actual: 5
# Sample Test Data 5231: Predicted: 6, Actual: 6
# Sample Test Data 5232: Predicted: 8, Actual: 8
# Sample Test Data 5233: Predicted: 1, Actual: 1
# Sample Test Data 5234: Predicted: 9, Actual: 9
# Sample Test Data 5235: Predicted: 7, Actual: 7
# Sample Test Data 5236: Predicted: 6, Actual: 6
# Sample Test Data 5237: Predicted: 8, Actual: 8
# Sample Test Data 5238: Predicted: 3, Actual: 3
# Sample Test Data 5239: Predicted: 7, Actual: 7
# Sample Test Data 5240: Predicted: 4, Actual: 4
# Sample Test Data 5241: Predicted: 7, Actual: 7
# Sample Test Data 5242: Predicted: 0, Actual: 0
# Sample Test Data 5243: Predicted: 9, Actual: 9
# Sample Test Data 5244: Predicted: 0, Actual: 0
# Sample Test Data 5245: Predicted: 0, Actual: 0
# Sample Test Data 5246: Predicted: 3, Actual: 3
# Sample Test Data 5247: Predicted: 7, Actual: 7
# Sample Test Data 5248: Predicted: 9, Actual: 9
# Sample Test Data 5249: Predicted: 3, Actual: 3
# Sample Test Data 5250: Predicted: 0, Actual: 0
# Sample Test Data 5251: Predicted: 2, Actual: 2
# Sample Test Data 5252: Predicted: 0, Actual: 0
# Sample Test Data 5253: Predicted: 1, Actual: 1
# Sample Test Data 5254: Predicted: 0, Actual: 0
# Sample Test Data 5255: Predicted: 1, Actual: 1
# Sample Test Data 5256: Predicted: 0, Actual: 0
# Sample Test Data 5257: Predicted: 4, Actual: 4
# Sample Test Data 5258: Predicted: 0, Actual: 0
# Sample Test Data 5259: Predicted: 1, Actual: 1
# Sample Test Data 5260: Predicted: 0, Actual: 0
# Sample Test Data 5261: Predicted: 4, Actual: 4
# Sample Test Data 5262: Predicted: 7, Actual: 7
# Sample Test Data 5263: Predicted: 9, Actual: 9
# Sample Test Data 5264: Predicted: 6, Actual: 6
# Sample Test Data 5265: Predicted: 2, Actual: 2
# Sample Test Data 5266: Predicted: 6, Actual: 6
# Sample Test Data 5267: Predicted: 2, Actual: 2
# Sample Test Data 5268: Predicted: 2, Actual: 2
# Sample Test Data 5269: Predicted: 9, Actual: 9
# Sample Test Data 5270: Predicted: 9, Actual: 9
# Sample Test Data 5271: Predicted: 0, Actual: 0
# Sample Test Data 5272: Predicted: 1, Actual: 1
# Sample Test Data 5273: Predicted: 2, Actual: 2
# Sample Test Data 5274: Predicted: 3, Actual: 3
# Sample Test Data 5275: Predicted: 4, Actual: 4
# Sample Test Data 5276: Predicted: 5, Actual: 5
# Sample Test Data 5277: Predicted: 6, Actual: 6
# Sample Test Data 5278: Predicted: 7, Actual: 7
# Sample Test Data 5279: Predicted: 9, Actual: 8
# Sample Test Data 5280: Predicted: 9, Actual: 9
# Sample Test Data 5281: Predicted: 0, Actual: 0
# Sample Test Data 5282: Predicted: 1, Actual: 1
# Sample Test Data 5283: Predicted: 2, Actual: 2
# Sample Test Data 5284: Predicted: 3, Actual: 3
# Sample Test Data 5285: Predicted: 4, Actual: 4
# Sample Test Data 5286: Predicted: 5, Actual: 5
# Sample Test Data 5287: Predicted: 6, Actual: 6
# Sample Test Data 5288: Predicted: 7, Actual: 7
# Sample Test Data 5289: Predicted: 9, Actual: 8
# Sample Test Data 5290: Predicted: 9, Actual: 9
# Sample Test Data 5291: Predicted: 0, Actual: 0
# Sample Test Data 5292: Predicted: 1, Actual: 1
# Sample Test Data 5293: Predicted: 2, Actual: 2
# Sample Test Data 5294: Predicted: 3, Actual: 3
# Sample Test Data 5295: Predicted: 4, Actual: 4
# Sample Test Data 5296: Predicted: 5, Actual: 5
# Sample Test Data 5297: Predicted: 6, Actual: 6
# Sample Test Data 5298: Predicted: 7, Actual: 7
# Sample Test Data 5299: Predicted: 8, Actual: 8
# Sample Test Data 5300: Predicted: 9, Actual: 9
# Sample Test Data 5301: Predicted: 8, Actual: 8
# Sample Test Data 5302: Predicted: 0, Actual: 0
# Sample Test Data 5303: Predicted: 5, Actual: 5
# Sample Test Data 5304: Predicted: 6, Actual: 6
# Sample Test Data 5305: Predicted: 6, Actual: 6
# Sample Test Data 5306: Predicted: 0, Actual: 0
# Sample Test Data 5307: Predicted: 8, Actual: 8
# Sample Test Data 5308: Predicted: 0, Actual: 0
# Sample Test Data 5309: Predicted: 2, Actual: 2
# Sample Test Data 5310: Predicted: 3, Actual: 3
# Sample Test Data 5311: Predicted: 7, Actual: 7
# Sample Test Data 5312: Predicted: 9, Actual: 9
# Sample Test Data 5313: Predicted: 4, Actual: 4
# Sample Test Data 5314: Predicted: 7, Actual: 7
# Sample Test Data 5315: Predicted: 1, Actual: 1
# Sample Test Data 5316: Predicted: 9, Actual: 9
# Sample Test Data 5317: Predicted: 1, Actual: 1
# Sample Test Data 5318: Predicted: 7, Actual: 7
# Sample Test Data 5319: Predicted: 1, Actual: 1
# Sample Test Data 5320: Predicted: 4, Actual: 4
# Sample Test Data 5321: Predicted: 0, Actual: 0
# Sample Test Data 5322: Predicted: 0, Actual: 0
# Sample Test Data 5323: Predicted: 4, Actual: 4
# Sample Test Data 5324: Predicted: 1, Actual: 1
# Sample Test Data 5325: Predicted: 7, Actual: 7
# Sample Test Data 5326: Predicted: 5, Actual: 5
# Sample Test Data 5327: Predicted: 7, Actual: 7
# Sample Test Data 5328: Predicted: 1, Actual: 1
# Sample Test Data 5329: Predicted: 3, Actual: 3
# Sample Test Data 5330: Predicted: 3, Actual: 3
# Sample Test Data 5331: Predicted: 3, Actual: 3
# Sample Test Data 5332: Predicted: 1, Actual: 1
# Sample Test Data 5333: Predicted: 6, Actual: 6
# Sample Test Data 5334: Predicted: 9, Actual: 9
# Sample Test Data 5335: Predicted: 7, Actual: 7
# Sample Test Data 5336: Predicted: 4, Actual: 4
# Sample Test Data 5337: Predicted: 3, Actual: 3
# Sample Test Data 5338: Predicted: 0, Actual: 0
# Sample Test Data 5339: Predicted: 2, Actual: 2
# Sample Test Data 5340: Predicted: 5, Actual: 5
# Sample Test Data 5341: Predicted: 2, Actual: 2
# Sample Test Data 5342: Predicted: 6, Actual: 6
# Sample Test Data 5343: Predicted: 0, Actual: 0
# Sample Test Data 5344: Predicted: 8, Actual: 8
# Sample Test Data 5345: Predicted: 9, Actual: 9
# Sample Test Data 5346: Predicted: 4, Actual: 4
# Sample Test Data 5347: Predicted: 3, Actual: 3
# Sample Test Data 5348: Predicted: 5, Actual: 5
# Sample Test Data 5349: Predicted: 4, Actual: 4
# Sample Test Data 5350: Predicted: 8, Actual: 8
# Sample Test Data 5351: Predicted: 1, Actual: 1
# Sample Test Data 5352: Predicted: 5, Actual: 5
# Sample Test Data 5353: Predicted: 9, Actual: 9
# Sample Test Data 5354: Predicted: 0, Actual: 0
# Sample Test Data 5355: Predicted: 6, Actual: 6
# Sample Test Data 5356: Predicted: 4, Actual: 4
# Sample Test Data 5357: Predicted: 3, Actual: 3
# Sample Test Data 5358: Predicted: 6, Actual: 6
# Sample Test Data 5359: Predicted: 3, Actual: 3
# Sample Test Data 5360: Predicted: 3, Actual: 3
# Sample Test Data 5361: Predicted: 8, Actual: 8
# Sample Test Data 5362: Predicted: 1, Actual: 1
# Sample Test Data 5363: Predicted: 4, Actual: 4
# Sample Test Data 5364: Predicted: 7, Actual: 7
# Sample Test Data 5365: Predicted: 5, Actual: 5
# Sample Test Data 5366: Predicted: 7, Actual: 7
# Sample Test Data 5367: Predicted: 2, Actual: 2
# Sample Test Data 5368: Predicted: 2, Actual: 2
# Sample Test Data 5369: Predicted: 0, Actual: 0
# Sample Test Data 5370: Predicted: 0, Actual: 0
# Sample Test Data 5371: Predicted: 1, Actual: 1
# Sample Test Data 5372: Predicted: 7, Actual: 7
# Sample Test Data 5373: Predicted: 7, Actual: 7
# Sample Test Data 5374: Predicted: 9, Actual: 9
# Sample Test Data 5375: Predicted: 5, Actual: 5
# Sample Test Data 5376: Predicted: 9, Actual: 9
# Sample Test Data 5377: Predicted: 8, Actual: 8
# Sample Test Data 5378: Predicted: 9, Actual: 9
# Sample Test Data 5379: Predicted: 6, Actual: 6
# Sample Test Data 5380: Predicted: 8, Actual: 8
# Sample Test Data 5381: Predicted: 8, Actual: 8
# Sample Test Data 5382: Predicted: 2, Actual: 2
# Sample Test Data 5383: Predicted: 3, Actual: 3
# Sample Test Data 5384: Predicted: 6, Actual: 6
# Sample Test Data 5385: Predicted: 1, Actual: 1
# Sample Test Data 5386: Predicted: 2, Actual: 2
# Sample Test Data 5387: Predicted: 9, Actual: 9
# Sample Test Data 5388: Predicted: 8, Actual: 8
# Sample Test Data 5389: Predicted: 9, Actual: 9
# Sample Test Data 5390: Predicted: 5, Actual: 5
# Sample Test Data 5391: Predicted: 2, Actual: 2
# Sample Test Data 5392: Predicted: 6, Actual: 6
# Sample Test Data 5393: Predicted: 2, Actual: 2
# Sample Test Data 5394: Predicted: 4, Actual: 4
# Sample Test Data 5395: Predicted: 8, Actual: 8
# Sample Test Data 5396: Predicted: 4, Actual: 4
# Sample Test Data 5397: Predicted: 6, Actual: 6
# Sample Test Data 5398: Predicted: 5, Actual: 5
# Sample Test Data 5399: Predicted: 0, Actual: 0
# Sample Test Data 5400: Predicted: 1, Actual: 1
# Sample Test Data 5401: Predicted: 5, Actual: 5
# Sample Test Data 5402: Predicted: 6, Actual: 6
# Sample Test Data 5403: Predicted: 7, Actual: 7
# Sample Test Data 5404: Predicted: 8, Actual: 8
# Sample Test Data 5405: Predicted: 9, Actual: 9
# Sample Test Data 5406: Predicted: 0, Actual: 0
# Sample Test Data 5407: Predicted: 1, Actual: 1
# Sample Test Data 5408: Predicted: 2, Actual: 2
# Sample Test Data 5409: Predicted: 3, Actual: 3
# Sample Test Data 5410: Predicted: 4, Actual: 4
# Sample Test Data 5411: Predicted: 5, Actual: 5
# Sample Test Data 5412: Predicted: 6, Actual: 6
# Sample Test Data 5413: Predicted: 7, Actual: 7
# Sample Test Data 5414: Predicted: 8, Actual: 8
# Sample Test Data 5415: Predicted: 9, Actual: 9
# Sample Test Data 5416: Predicted: 0, Actual: 0
# Sample Test Data 5417: Predicted: 1, Actual: 1
# Sample Test Data 5418: Predicted: 2, Actual: 2
# Sample Test Data 5419: Predicted: 3, Actual: 3
# Sample Test Data 5420: Predicted: 4, Actual: 4
# Sample Test Data 5421: Predicted: 5, Actual: 5
# Sample Test Data 5422: Predicted: 6, Actual: 6
# Sample Test Data 5423: Predicted: 7, Actual: 7
# Sample Test Data 5424: Predicted: 8, Actual: 8
# Sample Test Data 5425: Predicted: 9, Actual: 9
# Sample Test Data 5426: Predicted: 7, Actual: 7
# Sample Test Data 5427: Predicted: 4, Actual: 4
# Sample Test Data 5428: Predicted: 2, Actual: 2
# Sample Test Data 5429: Predicted: 0, Actual: 0
# Sample Test Data 5430: Predicted: 9, Actual: 9
# Sample Test Data 5431: Predicted: 0, Actual: 0
# Sample Test Data 5432: Predicted: 1, Actual: 1
# Sample Test Data 5433: Predicted: 5, Actual: 5
# Sample Test Data 5434: Predicted: 8, Actual: 8
# Sample Test Data 5435: Predicted: 8, Actual: 8
# Sample Test Data 5436: Predicted: 0, Actual: 0
# Sample Test Data 5437: Predicted: 2, Actual: 2
# Sample Test Data 5438: Predicted: 7, Actual: 7
# Sample Test Data 5439: Predicted: 8, Actual: 8
# Sample Test Data 5440: Predicted: 4, Actual: 4
# Sample Test Data 5441: Predicted: 4, Actual: 4
# Sample Test Data 5442: Predicted: 6, Actual: 6
# Sample Test Data 5443: Predicted: 1, Actual: 1
# Sample Test Data 5444: Predicted: 0, Actual: 0
# Sample Test Data 5445: Predicted: 4, Actual: 4
# Sample Test Data 5446: Predicted: 5, Actual: 5
# Sample Test Data 5447: Predicted: 3, Actual: 3
# Sample Test Data 5448: Predicted: 9, Actual: 9
# Sample Test Data 5449: Predicted: 4, Actual: 4
# Sample Test Data 5450: Predicted: 2, Actual: 2
# Sample Test Data 5451: Predicted: 0, Actual: 0
# Sample Test Data 5452: Predicted: 5, Actual: 5
# Sample Test Data 5453: Predicted: 0, Actual: 0
# Sample Test Data 5454: Predicted: 1, Actual: 1
# Sample Test Data 5455: Predicted: 3, Actual: 3
# Sample Test Data 5456: Predicted: 2, Actual: 2
# Sample Test Data 5457: Predicted: 9, Actual: 9
# Sample Test Data 5458: Predicted: 8, Actual: 1
# Sample Test Data 5459: Predicted: 6, Actual: 6
# Sample Test Data 5460: Predicted: 0, Actual: 0
# Sample Test Data 5461: Predicted: 1, Actual: 1
# Sample Test Data 5462: Predicted: 1, Actual: 1
# Sample Test Data 5463: Predicted: 8, Actual: 8
# Sample Test Data 5464: Predicted: 0, Actual: 0
# Sample Test Data 5465: Predicted: 4, Actual: 4
# Sample Test Data 5466: Predicted: 7, Actual: 7
# Sample Test Data 5467: Predicted: 7, Actual: 7
# Sample Test Data 5468: Predicted: 6, Actual: 6
# Sample Test Data 5469: Predicted: 3, Actual: 3
# Sample Test Data 5470: Predicted: 6, Actual: 6
# Sample Test Data 5471: Predicted: 0, Actual: 0
# Sample Test Data 5472: Predicted: 7, Actual: 7
# Sample Test Data 5473: Predicted: 3, Actual: 3
# Sample Test Data 5474: Predicted: 5, Actual: 5
# Sample Test Data 5475: Predicted: 4, Actual: 4
# Sample Test Data 5476: Predicted: 2, Actual: 2
# Sample Test Data 5477: Predicted: 4, Actual: 4
# Sample Test Data 5478: Predicted: 1, Actual: 1
# Sample Test Data 5479: Predicted: 8, Actual: 8
# Sample Test Data 5480: Predicted: 3, Actual: 3
# Sample Test Data 5481: Predicted: 5, Actual: 5
# Sample Test Data 5482: Predicted: 6, Actual: 6
# Sample Test Data 5483: Predicted: 7, Actual: 7
# Sample Test Data 5484: Predicted: 0, Actual: 0
# Sample Test Data 5485: Predicted: 6, Actual: 6
# Sample Test Data 5486: Predicted: 7, Actual: 7
# Sample Test Data 5487: Predicted: 1, Actual: 1
# Sample Test Data 5488: Predicted: 2, Actual: 2
# Sample Test Data 5489: Predicted: 5, Actual: 5
# Sample Test Data 5490: Predicted: 8, Actual: 8
# Sample Test Data 5491: Predicted: 1, Actual: 1
# Sample Test Data 5492: Predicted: 9, Actual: 9
# Sample Test Data 5493: Predicted: 3, Actual: 3
# Sample Test Data 5494: Predicted: 8, Actual: 8
# Sample Test Data 5495: Predicted: 2, Actual: 2
# Sample Test Data 5496: Predicted: 8, Actual: 8
# Sample Test Data 5497: Predicted: 7, Actual: 7
# Sample Test Data 5498: Predicted: 6, Actual: 6
# Sample Test Data 5499: Predicted: 7, Actual: 7
# Sample Test Data 5500: Predicted: 1, Actual: 1
# Sample Test Data 5501: Predicted: 4, Actual: 4
# Sample Test Data 5502: Predicted: 6, Actual: 6
# Sample Test Data 5503: Predicted: 2, Actual: 2
# Sample Test Data 5504: Predicted: 9, Actual: 9
# Sample Test Data 5505: Predicted: 3, Actual: 3
# Sample Test Data 5506: Predicted: 0, Actual: 0
# Sample Test Data 5507: Predicted: 1, Actual: 1
# Sample Test Data 5508: Predicted: 2, Actual: 2
# Sample Test Data 5509: Predicted: 3, Actual: 3
# Sample Test Data 5510: Predicted: 4, Actual: 4
# Sample Test Data 5511: Predicted: 5, Actual: 5
# Sample Test Data 5512: Predicted: 6, Actual: 6
# Sample Test Data 5513: Predicted: 7, Actual: 7
# Sample Test Data 5514: Predicted: 0, Actual: 0
# Sample Test Data 5515: Predicted: 1, Actual: 1
# Sample Test Data 5516: Predicted: 2, Actual: 2
# Sample Test Data 5517: Predicted: 3, Actual: 3
# Sample Test Data 5518: Predicted: 4, Actual: 4
# Sample Test Data 5519: Predicted: 5, Actual: 5
# Sample Test Data 5520: Predicted: 0, Actual: 0
# Sample Test Data 5521: Predicted: 1, Actual: 1
# Sample Test Data 5522: Predicted: 2, Actual: 2
# Sample Test Data 5523: Predicted: 8, Actual: 8
# Sample Test Data 5524: Predicted: 9, Actual: 9
# Sample Test Data 5525: Predicted: 1, Actual: 1
# Sample Test Data 5526: Predicted: 4, Actual: 4
# Sample Test Data 5527: Predicted: 0, Actual: 0
# Sample Test Data 5528: Predicted: 9, Actual: 9
# Sample Test Data 5529: Predicted: 5, Actual: 5
# Sample Test Data 5530: Predicted: 0, Actual: 0
# Sample Test Data 5531: Predicted: 8, Actual: 8
# Sample Test Data 5532: Predicted: 0, Actual: 0
# Sample Test Data 5533: Predicted: 7, Actual: 7
# Sample Test Data 5534: Predicted: 7, Actual: 7
# Sample Test Data 5535: Predicted: 1, Actual: 1
# Sample Test Data 5536: Predicted: 1, Actual: 1
# Sample Test Data 5537: Predicted: 2, Actual: 2
# Sample Test Data 5538: Predicted: 9, Actual: 9
# Sample Test Data 5539: Predicted: 3, Actual: 3
# Sample Test Data 5540: Predicted: 6, Actual: 6
# Sample Test Data 5541: Predicted: 7, Actual: 7
# Sample Test Data 5542: Predicted: 2, Actual: 2
# Sample Test Data 5543: Predicted: 3, Actual: 3
# Sample Test Data 5544: Predicted: 8, Actual: 8
# Sample Test Data 5545: Predicted: 1, Actual: 1
# Sample Test Data 5546: Predicted: 2, Actual: 2
# Sample Test Data 5547: Predicted: 9, Actual: 9
# Sample Test Data 5548: Predicted: 8, Actual: 8
# Sample Test Data 5549: Predicted: 8, Actual: 8
# Sample Test Data 5550: Predicted: 7, Actual: 7
# Sample Test Data 5551: Predicted: 1, Actual: 1
# Sample Test Data 5552: Predicted: 7, Actual: 7
# Sample Test Data 5553: Predicted: 1, Actual: 1
# Sample Test Data 5554: Predicted: 1, Actual: 1
# Sample Test Data 5555: Predicted: 0, Actual: 0
# Sample Test Data 5556: Predicted: 3, Actual: 3
# Sample Test Data 5557: Predicted: 4, Actual: 4
# Sample Test Data 5558: Predicted: 2, Actual: 2
# Sample Test Data 5559: Predicted: 6, Actual: 6
# Sample Test Data 5560: Predicted: 4, Actual: 4
# Sample Test Data 5561: Predicted: 7, Actual: 7
# Sample Test Data 5562: Predicted: 4, Actual: 4
# Sample Test Data 5563: Predicted: 2, Actual: 2
# Sample Test Data 5564: Predicted: 7, Actual: 7
# Sample Test Data 5565: Predicted: 4, Actual: 4
# Sample Test Data 5566: Predicted: 9, Actual: 9
# Sample Test Data 5567: Predicted: 1, Actual: 1
# Sample Test Data 5568: Predicted: 0, Actual: 0
# Sample Test Data 5569: Predicted: 6, Actual: 6
# Sample Test Data 5570: Predicted: 8, Actual: 8
# Sample Test Data 5571: Predicted: 5, Actual: 5
# Sample Test Data 5572: Predicted: 5, Actual: 5
# Sample Test Data 5573: Predicted: 5, Actual: 5
# Sample Test Data 5574: Predicted: 3, Actual: 3
# Sample Test Data 5575: Predicted: 5, Actual: 5
# Sample Test Data 5576: Predicted: 9, Actual: 9
# Sample Test Data 5577: Predicted: 7, Actual: 7
# Sample Test Data 5578: Predicted: 4, Actual: 4
# Sample Test Data 5579: Predicted: 8, Actual: 8
# Sample Test Data 5580: Predicted: 5, Actual: 5
# Sample Test Data 5581: Predicted: 9, Actual: 9
# Sample Test Data 5582: Predicted: 6, Actual: 6
# Sample Test Data 5583: Predicted: 9, Actual: 9
# Sample Test Data 5584: Predicted: 3, Actual: 3
# Sample Test Data 5585: Predicted: 0, Actual: 0
# Sample Test Data 5586: Predicted: 3, Actual: 3
# Sample Test Data 5587: Predicted: 8, Actual: 8
# Sample Test Data 5588: Predicted: 9, Actual: 9
# Sample Test Data 5589: Predicted: 1, Actual: 1
# Sample Test Data 5590: Predicted: 8, Actual: 8
# Sample Test Data 5591: Predicted: 1, Actual: 1
# Sample Test Data 5592: Predicted: 6, Actual: 6
# Sample Test Data 5593: Predicted: 0, Actual: 0
# Sample Test Data 5594: Predicted: 0, Actual: 0
# Sample Test Data 5595: Predicted: 1, Actual: 1
# Sample Test Data 5596: Predicted: 2, Actual: 2
# Sample Test Data 5597: Predicted: 3, Actual: 3
# Sample Test Data 5598: Predicted: 4, Actual: 4
# Sample Test Data 5599: Predicted: 5, Actual: 5
# Sample Test Data 5600: Predicted: 6, Actual: 6
# Sample Test Data 5601: Predicted: 9, Actual: 7
# Sample Test Data 5602: Predicted: 8, Actual: 8
# Sample Test Data 5603: Predicted: 9, Actual: 9
# Sample Test Data 5604: Predicted: 0, Actual: 0
# Sample Test Data 5605: Predicted: 1, Actual: 1
# Sample Test Data 5606: Predicted: 2, Actual: 2
# Sample Test Data 5607: Predicted: 3, Actual: 3
# Sample Test Data 5608: Predicted: 4, Actual: 4
# Sample Test Data 5609: Predicted: 5, Actual: 5
# Sample Test Data 5610: Predicted: 6, Actual: 6
# Sample Test Data 5611: Predicted: 7, Actual: 7
# Sample Test Data 5612: Predicted: 8, Actual: 8
# Sample Test Data 5613: Predicted: 9, Actual: 9
# Sample Test Data 5614: Predicted: 0, Actual: 0
# Sample Test Data 5615: Predicted: 1, Actual: 1
# Sample Test Data 5616: Predicted: 2, Actual: 2
# Sample Test Data 5617: Predicted: 3, Actual: 3
# Sample Test Data 5618: Predicted: 4, Actual: 4
# Sample Test Data 5619: Predicted: 5, Actual: 5
# Sample Test Data 5620: Predicted: 6, Actual: 6
# Sample Test Data 5621: Predicted: 7, Actual: 7
# Sample Test Data 5622: Predicted: 8, Actual: 8
# Sample Test Data 5623: Predicted: 9, Actual: 9
# Sample Test Data 5624: Predicted: 3, Actual: 3
# Sample Test Data 5625: Predicted: 5, Actual: 5
# Sample Test Data 5626: Predicted: 3, Actual: 3
# Sample Test Data 5627: Predicted: 2, Actual: 2
# Sample Test Data 5628: Predicted: 9, Actual: 9
# Sample Test Data 5629: Predicted: 3, Actual: 3
# Sample Test Data 5630: Predicted: 2, Actual: 2
# Sample Test Data 5631: Predicted: 1, Actual: 1
# Sample Test Data 5632: Predicted: 4, Actual: 4
# Sample Test Data 5633: Predicted: 5, Actual: 5
# Sample Test Data 5634: Predicted: 5, Actual: 5
# Sample Test Data 5635: Predicted: 3, Actual: 2
# Sample Test Data 5636: Predicted: 3, Actual: 3
# Sample Test Data 5637: Predicted: 2, Actual: 2
# Sample Test Data 5638: Predicted: 1, Actual: 1
# Sample Test Data 5639: Predicted: 3, Actual: 3
# Sample Test Data 5640: Predicted: 9, Actual: 9
# Sample Test Data 5641: Predicted: 7, Actual: 7
# Sample Test Data 5642: Predicted: 2, Actual: 2
# Sample Test Data 5643: Predicted: 1, Actual: 1
# Sample Test Data 5644: Predicted: 2, Actual: 2
# Sample Test Data 5645: Predicted: 8, Actual: 8
# Sample Test Data 5646: Predicted: 9, Actual: 9
# Sample Test Data 5647: Predicted: 1, Actual: 1
# Sample Test Data 5648: Predicted: 8, Actual: 8
# Sample Test Data 5649: Predicted: 8, Actual: 8
# Sample Test Data 5650: Predicted: 7, Actual: 7
# Sample Test Data 5651: Predicted: 8, Actual: 8
# Sample Test Data 5652: Predicted: 1, Actual: 1
# Sample Test Data 5653: Predicted: 0, Actual: 0
# Sample Test Data 5654: Predicted: 0, Actual: 0
# Sample Test Data 5655: Predicted: 9, Actual: 7
# Sample Test Data 5656: Predicted: 7, Actual: 7
# Sample Test Data 5657: Predicted: 8, Actual: 8
# Sample Test Data 5658: Predicted: 7, Actual: 7
# Sample Test Data 5659: Predicted: 5, Actual: 5
# Sample Test Data 5660: Predicted: 0, Actual: 0
# Sample Test Data 5661: Predicted: 6, Actual: 6
# Sample Test Data 5662: Predicted: 1, Actual: 1
# Sample Test Data 5663: Predicted: 5, Actual: 5
# Sample Test Data 5664: Predicted: 7, Actual: 7
# Sample Test Data 5665: Predicted: 4, Actual: 4
# Sample Test Data 5666: Predicted: 6, Actual: 6
# Sample Test Data 5667: Predicted: 1, Actual: 1
# Sample Test Data 5668: Predicted: 2, Actual: 2
# Sample Test Data 5669: Predicted: 5, Actual: 5
# Sample Test Data 5670: Predicted: 0, Actual: 0
# Sample Test Data 5671: Predicted: 7, Actual: 7
# Sample Test Data 5672: Predicted: 9, Actual: 9
# Sample Test Data 5673: Predicted: 9, Actual: 9
# Sample Test Data 5674: Predicted: 0, Actual: 0
# Sample Test Data 5675: Predicted: 3, Actual: 3
# Sample Test Data 5676: Predicted: 8, Actual: 8
# Sample Test Data 5677: Predicted: 4, Actual: 4
# Sample Test Data 5678: Predicted: 4, Actual: 4
# Sample Test Data 5679: Predicted: 8, Actual: 8
# Sample Test Data 5680: Predicted: 1, Actual: 1
# Sample Test Data 5681: Predicted: 8, Actual: 8
# Sample Test Data 5682: Predicted: 6, Actual: 6
# Sample Test Data 5683: Predicted: 5, Actual: 5
# Sample Test Data 5684: Predicted: 9, Actual: 9
# Sample Test Data 5685: Predicted: 0, Actual: 0
# Sample Test Data 5686: Predicted: 0, Actual: 0
# Sample Test Data 5687: Predicted: 0, Actual: 0
# Sample Test Data 5688: Predicted: 3, Actual: 3
# Sample Test Data 5689: Predicted: 7, Actual: 7
# Sample Test Data 5690: Predicted: 1, Actual: 1
# Sample Test Data 5691: Predicted: 6, Actual: 6
# Sample Test Data 5692: Predicted: 4, Actual: 4
# Sample Test Data 5693: Predicted: 2, Actual: 2
# Sample Test Data 5694: Predicted: 6, Actual: 6
# Sample Test Data 5695: Predicted: 6, Actual: 6
# Sample Test Data 5696: Predicted: 0, Actual: 0
# Sample Test Data 5697: Predicted: 4, Actual: 4
# Sample Test Data 5698: Predicted: 5, Actual: 5
# Sample Test Data 5699: Predicted: 4, Actual: 4
# Sample Test Data 5700: Predicted: 1, Actual: 1
# Sample Test Data 5701: Predicted: 3, Actual: 3
# Sample Test Data 5702: Predicted: 8, Actual: 8
# Sample Test Data 5703: Predicted: 6, Actual: 6
# Sample Test Data 5704: Predicted: 3, Actual: 3
# Sample Test Data 5705: Predicted: 9, Actual: 9
# Sample Test Data 5706: Predicted: 9, Actual: 9
# Sample Test Data 5707: Predicted: 5, Actual: 5
# Sample Test Data 5708: Predicted: 9, Actual: 9
# Sample Test Data 5709: Predicted: 3, Actual: 3
# Sample Test Data 5710: Predicted: 9, Actual: 7
# Sample Test Data 5711: Predicted: 8, Actual: 8
# Sample Test Data 5712: Predicted: 5, Actual: 5
# Sample Test Data 5713: Predicted: 6, Actual: 6
# Sample Test Data 5714: Predicted: 4, Actual: 4
# Sample Test Data 5715: Predicted: 7, Actual: 7
# Sample Test Data 5716: Predicted: 6, Actual: 6
# Sample Test Data 5717: Predicted: 2, Actual: 2
# Sample Test Data 5718: Predicted: 2, Actual: 2
# Sample Test Data 5719: Predicted: 0, Actual: 0
# Sample Test Data 5720: Predicted: 9, Actual: 9
# Sample Test Data 5721: Predicted: 4, Actual: 4
# Sample Test Data 5722: Predicted: 0, Actual: 0
# Sample Test Data 5723: Predicted: 1, Actual: 1
# Sample Test Data 5724: Predicted: 2, Actual: 2
# Sample Test Data 5725: Predicted: 3, Actual: 3
# Sample Test Data 5726: Predicted: 4, Actual: 4
# Sample Test Data 5727: Predicted: 5, Actual: 5
# Sample Test Data 5728: Predicted: 6, Actual: 6
# Sample Test Data 5729: Predicted: 7, Actual: 7
# Sample Test Data 5730: Predicted: 8, Actual: 8
# Sample Test Data 5731: Predicted: 9, Actual: 9
# Sample Test Data 5732: Predicted: 0, Actual: 0
# Sample Test Data 5733: Predicted: 1, Actual: 1
# Sample Test Data 5734: Predicted: 2, Actual: 2
# Sample Test Data 5735: Predicted: 3, Actual: 3
# Sample Test Data 5736: Predicted: 1, Actual: 5
# Sample Test Data 5737: Predicted: 6, Actual: 6
# Sample Test Data 5738: Predicted: 0, Actual: 0
# Sample Test Data 5739: Predicted: 1, Actual: 1
# Sample Test Data 5740: Predicted: 2, Actual: 2
# Sample Test Data 5741: Predicted: 3, Actual: 3
# Sample Test Data 5742: Predicted: 4, Actual: 4
# Sample Test Data 5743: Predicted: 5, Actual: 5
# Sample Test Data 5744: Predicted: 6, Actual: 6
# Sample Test Data 5745: Predicted: 8, Actual: 8
# Sample Test Data 5746: Predicted: 7, Actual: 7
# Sample Test Data 5747: Predicted: 1, Actual: 1
# Sample Test Data 5748: Predicted: 3, Actual: 3
# Sample Test Data 5749: Predicted: 2, Actual: 2
# Sample Test Data 5750: Predicted: 2, Actual: 8
# Sample Test Data 5751: Predicted: 0, Actual: 0
# Sample Test Data 5752: Predicted: 7, Actual: 7
# Sample Test Data 5753: Predicted: 5, Actual: 5
# Sample Test Data 5754: Predicted: 9, Actual: 9
# Sample Test Data 5755: Predicted: 9, Actual: 9
# Sample Test Data 5756: Predicted: 6, Actual: 6
# Sample Test Data 5757: Predicted: 0, Actual: 0
# Sample Test Data 5758: Predicted: 9, Actual: 9
# Sample Test Data 5759: Predicted: 4, Actual: 4
# Sample Test Data 5760: Predicted: 1, Actual: 1
# Sample Test Data 5761: Predicted: 3, Actual: 3
# Sample Test Data 5762: Predicted: 2, Actual: 2
# Sample Test Data 5763: Predicted: 1, Actual: 1
# Sample Test Data 5764: Predicted: 2, Actual: 2
# Sample Test Data 5765: Predicted: 3, Actual: 3
# Sample Test Data 5766: Predicted: 8, Actual: 8
# Sample Test Data 5767: Predicted: 3, Actual: 3
# Sample Test Data 5768: Predicted: 2, Actual: 2
# Sample Test Data 5769: Predicted: 6, Actual: 6
# Sample Test Data 5770: Predicted: 5, Actual: 5
# Sample Test Data 5771: Predicted: 6, Actual: 6
# Sample Test Data 5772: Predicted: 8, Actual: 8
# Sample Test Data 5773: Predicted: 2, Actual: 2
# Sample Test Data 5774: Predicted: 7, Actual: 7
# Sample Test Data 5775: Predicted: 4, Actual: 4
# Sample Test Data 5776: Predicted: 8, Actual: 8
# Sample Test Data 5777: Predicted: 1, Actual: 1
# Sample Test Data 5778: Predicted: 8, Actual: 8
# Sample Test Data 5779: Predicted: 0, Actual: 0
# Sample Test Data 5780: Predicted: 5, Actual: 5
# Sample Test Data 5781: Predicted: 3, Actual: 3
# Sample Test Data 5782: Predicted: 9, Actual: 9
# Sample Test Data 5783: Predicted: 4, Actual: 4
# Sample Test Data 5784: Predicted: 1, Actual: 1
# Sample Test Data 5785: Predicted: 9, Actual: 9
# Sample Test Data 5786: Predicted: 2, Actual: 2
# Sample Test Data 5787: Predicted: 1, Actual: 1
# Sample Test Data 5788: Predicted: 9, Actual: 9
# Sample Test Data 5789: Predicted: 6, Actual: 6
# Sample Test Data 5790: Predicted: 7, Actual: 7
# Sample Test Data 5791: Predicted: 9, Actual: 9
# Sample Test Data 5792: Predicted: 0, Actual: 0
# Sample Test Data 5793: Predicted: 4, Actual: 4
# Sample Test Data 5794: Predicted: 6, Actual: 6
# Sample Test Data 5795: Predicted: 1, Actual: 1
# Sample Test Data 5796: Predicted: 7, Actual: 7
# Sample Test Data 5797: Predicted: 3, Actual: 3
# Sample Test Data 5798: Predicted: 8, Actual: 8
# Sample Test Data 5799: Predicted: 7, Actual: 7
# Sample Test Data 5800: Predicted: 2, Actual: 2
# Sample Test Data 5801: Predicted: 9, Actual: 9
# Sample Test Data 5802: Predicted: 6, Actual: 6
# Sample Test Data 5803: Predicted: 5, Actual: 5
# Sample Test Data 5804: Predicted: 8, Actual: 8
# Sample Test Data 5805: Predicted: 3, Actual: 3
# Sample Test Data 5806: Predicted: 9, Actual: 9
# Sample Test Data 5807: Predicted: 0, Actual: 0
# Sample Test Data 5808: Predicted: 5, Actual: 5
# Sample Test Data 5809: Predicted: 7, Actual: 7
# Sample Test Data 5810: Predicted: 1, Actual: 1
# Sample Test Data 5811: Predicted: 6, Actual: 6
# Sample Test Data 5812: Predicted: 1, Actual: 1
# Sample Test Data 5813: Predicted: 0, Actual: 0
# Sample Test Data 5814: Predicted: 9, Actual: 9
# Sample Test Data 5815: Predicted: 3, Actual: 3
# Sample Test Data 5816: Predicted: 3, Actual: 3
# Sample Test Data 5817: Predicted: 4, Actual: 4
# Sample Test Data 5818: Predicted: 4, Actual: 4
# Sample Test Data 5819: Predicted: 0, Actual: 0
# Sample Test Data 5820: Predicted: 6, Actual: 6
# Sample Test Data 5821: Predicted: 2, Actual: 2
# Sample Test Data 5822: Predicted: 5, Actual: 5
# Sample Test Data 5823: Predicted: 4, Actual: 4
# Sample Test Data 5824: Predicted: 2, Actual: 2
# Sample Test Data 5825: Predicted: 3, Actual: 3
# Sample Test Data 5826: Predicted: 4, Actual: 4
# Sample Test Data 5827: Predicted: 6, Actual: 6
# Sample Test Data 5828: Predicted: 0, Actual: 0
# Sample Test Data 5829: Predicted: 0, Actual: 0
# Sample Test Data 5830: Predicted: 2, Actual: 2
# Sample Test Data 5831: Predicted: 0, Actual: 0
# Sample Test Data 5832: Predicted: 1, Actual: 1
# Sample Test Data 5833: Predicted: 4, Actual: 4
# Sample Test Data 5834: Predicted: 5, Actual: 5
# Sample Test Data 5835: Predicted: 6, Actual: 6
# Sample Test Data 5836: Predicted: 9, Actual: 7
# Sample Test Data 5837: Predicted: 8, Actual: 8
# Sample Test Data 5838: Predicted: 9, Actual: 9
# Sample Test Data 5839: Predicted: 0, Actual: 0
# Sample Test Data 5840: Predicted: 1, Actual: 1
# Sample Test Data 5841: Predicted: 2, Actual: 2
# Sample Test Data 5842: Predicted: 3, Actual: 3
# Sample Test Data 5843: Predicted: 4, Actual: 4
# Sample Test Data 5844: Predicted: 5, Actual: 5
# Sample Test Data 5845: Predicted: 6, Actual: 6
# Sample Test Data 5846: Predicted: 7, Actual: 7
# Sample Test Data 5847: Predicted: 8, Actual: 8
# Sample Test Data 5848: Predicted: 0, Actual: 0
# Sample Test Data 5849: Predicted: 1, Actual: 1
# Sample Test Data 5850: Predicted: 2, Actual: 2
# Sample Test Data 5851: Predicted: 3, Actual: 3
# Sample Test Data 5852: Predicted: 4, Actual: 4
# Sample Test Data 5853: Predicted: 5, Actual: 5
# Sample Test Data 5854: Predicted: 6, Actual: 6
# Sample Test Data 5855: Predicted: 7, Actual: 7
# Sample Test Data 5856: Predicted: 8, Actual: 8
# Sample Test Data 5857: Predicted: 9, Actual: 9
# Sample Test Data 5858: Predicted: 8, Actual: 8
# Sample Test Data 5859: Predicted: 7, Actual: 7
# Sample Test Data 5860: Predicted: 1, Actual: 1
# Sample Test Data 5861: Predicted: 3, Actual: 3
# Sample Test Data 5862: Predicted: 7, Actual: 7
# Sample Test Data 5863: Predicted: 5, Actual: 5
# Sample Test Data 5864: Predicted: 2, Actual: 2
# Sample Test Data 5865: Predicted: 8, Actual: 8
# Sample Test Data 5866: Predicted: 0, Actual: 0
# Sample Test Data 5867: Predicted: 7, Actual: 7
# Sample Test Data 5868: Predicted: 5, Actual: 5
# Sample Test Data 5869: Predicted: 9, Actual: 9
# Sample Test Data 5870: Predicted: 9, Actual: 9
# Sample Test Data 5871: Predicted: 0, Actual: 0
# Sample Test Data 5872: Predicted: 9, Actual: 9
# Sample Test Data 5873: Predicted: 1, Actual: 1
# Sample Test Data 5874: Predicted: 1, Actual: 1
# Sample Test Data 5875: Predicted: 5, Actual: 5
# Sample Test Data 5876: Predicted: 8, Actual: 8
# Sample Test Data 5877: Predicted: 8, Actual: 8
# Sample Test Data 5878: Predicted: 6, Actual: 6
# Sample Test Data 5879: Predicted: 3, Actual: 3
# Sample Test Data 5880: Predicted: 2, Actual: 2
# Sample Test Data 5881: Predicted: 1, Actual: 1
# Sample Test Data 5882: Predicted: 8, Actual: 8
# Sample Test Data 5883: Predicted: 3, Actual: 3
# Sample Test Data 5884: Predicted: 2, Actual: 2
# Sample Test Data 5885: Predicted: 6, Actual: 6
# Sample Test Data 5886: Predicted: 5, Actual: 5
# Sample Test Data 5887: Predicted: 6, Actual: 6
# Sample Test Data 5888: Predicted: 7, Actual: 7
# Sample Test Data 5889: Predicted: 4, Actual: 4
# Sample Test Data 5890: Predicted: 1, Actual: 1
# Sample Test Data 5891: Predicted: 0, Actual: 0
# Sample Test Data 5892: Predicted: 5, Actual: 5
# Sample Test Data 5893: Predicted: 3, Actual: 3
# Sample Test Data 5894: Predicted: 1, Actual: 1
# Sample Test Data 5895: Predicted: 9, Actual: 9
# Sample Test Data 5896: Predicted: 2, Actual: 2
# Sample Test Data 5897: Predicted: 1, Actual: 1
# Sample Test Data 5898: Predicted: 9, Actual: 9
# Sample Test Data 5899: Predicted: 6, Actual: 6
# Sample Test Data 5900: Predicted: 0, Actual: 0
# Sample Test Data 5901: Predicted: 4, Actual: 4
# Sample Test Data 5902: Predicted: 6, Actual: 6
# Sample Test Data 5903: Predicted: 1, Actual: 1
# Sample Test Data 5904: Predicted: 7, Actual: 7
# Sample Test Data 5905: Predicted: 3, Actual: 3
# Sample Test Data 5906: Predicted: 8, Actual: 8
# Sample Test Data 5907: Predicted: 7, Actual: 7
# Sample Test Data 5908: Predicted: 2, Actual: 2
# Sample Test Data 5909: Predicted: 9, Actual: 9
# Sample Test Data 5910: Predicted: 6, Actual: 6
# Sample Test Data 5911: Predicted: 5, Actual: 5
# Sample Test Data 5912: Predicted: 8, Actual: 8
# Sample Test Data 5913: Predicted: 3, Actual: 3
# Sample Test Data 5914: Predicted: 5, Actual: 5
# Sample Test Data 5915: Predicted: 7, Actual: 7
# Sample Test Data 5916: Predicted: 1, Actual: 1
# Sample Test Data 5917: Predicted: 6, Actual: 6
# Sample Test Data 5918: Predicted: 1, Actual: 1
# Sample Test Data 5919: Predicted: 0, Actual: 0
# Sample Test Data 5920: Predicted: 9, Actual: 9
# Sample Test Data 5921: Predicted: 6, Actual: 6
# Sample Test Data 5922: Predicted: 2, Actual: 2
# Sample Test Data 5923: Predicted: 5, Actual: 5
# Sample Test Data 5924: Predicted: 4, Actual: 4
# Sample Test Data 5925: Predicted: 2, Actual: 2
# Sample Test Data 5926: Predicted: 3, Actual: 3
# Sample Test Data 5927: Predicted: 4, Actual: 4
# Sample Test Data 5928: Predicted: 4, Actual: 4
# Sample Test Data 5929: Predicted: 6, Actual: 6
# Sample Test Data 5930: Predicted: 0, Actual: 0
# Sample Test Data 5931: Predicted: 0, Actual: 0
# Sample Test Data 5932: Predicted: 2, Actual: 2
# Sample Test Data 5933: Predicted: 0, Actual: 0
# Sample Test Data 5934: Predicted: 1, Actual: 1
# Sample Test Data 5935: Predicted: 2, Actual: 2
# Sample Test Data 5936: Predicted: 3, Actual: 3
# Sample Test Data 5937: Predicted: 4, Actual: 4
# Sample Test Data 5938: Predicted: 3, Actual: 5
# Sample Test Data 5939: Predicted: 6, Actual: 6
# Sample Test Data 5940: Predicted: 7, Actual: 7
# Sample Test Data 5941: Predicted: 8, Actual: 8
# Sample Test Data 5942: Predicted: 9, Actual: 9
# Sample Test Data 5943: Predicted: 0, Actual: 0
# Sample Test Data 5944: Predicted: 1, Actual: 1
# Sample Test Data 5945: Predicted: 2, Actual: 2
# Sample Test Data 5946: Predicted: 3, Actual: 3
# Sample Test Data 5947: Predicted: 4, Actual: 4
# Sample Test Data 5948: Predicted: 5, Actual: 5
# Sample Test Data 5949: Predicted: 6, Actual: 6
# Sample Test Data 5950: Predicted: 7, Actual: 7
# Sample Test Data 5951: Predicted: 8, Actual: 8
# Sample Test Data 5952: Predicted: 9, Actual: 9
# Sample Test Data 5953: Predicted: 0, Actual: 0
# Sample Test Data 5954: Predicted: 1, Actual: 1
# Sample Test Data 5955: Predicted: 2, Actual: 2
# Sample Test Data 5956: Predicted: 8, Actual: 3
# Sample Test Data 5957: Predicted: 4, Actual: 4
# Sample Test Data 5958: Predicted: 5, Actual: 5
# Sample Test Data 5959: Predicted: 6, Actual: 6
# Sample Test Data 5960: Predicted: 7, Actual: 7
# Sample Test Data 5961: Predicted: 8, Actual: 8
# Sample Test Data 5962: Predicted: 9, Actual: 9
# Sample Test Data 5963: Predicted: 8, Actual: 8
# Sample Test Data 5964: Predicted: 6, Actual: 6
# Sample Test Data 5965: Predicted: 5, Actual: 5
# Sample Test Data 5966: Predicted: 0, Actual: 0
# Sample Test Data 5967: Predicted: 6, Actual: 6
# Sample Test Data 5968: Predicted: 8, Actual: 8
# Sample Test Data 5969: Predicted: 9, Actual: 9
# Sample Test Data 5970: Predicted: 4, Actual: 4
# Sample Test Data 5971: Predicted: 1, Actual: 1
# Sample Test Data 5972: Predicted: 9, Actual: 9
# Sample Test Data 5973: Predicted: 5, Actual: 5
# Sample Test Data 5974: Predicted: 8, Actual: 3
# Sample Test Data 5975: Predicted: 0, Actual: 0
# Sample Test Data 5976: Predicted: 4, Actual: 4
# Sample Test Data 5977: Predicted: 8, Actual: 8
# Sample Test Data 5978: Predicted: 9, Actual: 9
# Sample Test Data 5979: Predicted: 1, Actual: 1
# Sample Test Data 5980: Predicted: 4, Actual: 4
# Sample Test Data 5981: Predicted: 0, Actual: 0
# Sample Test Data 5982: Predicted: 9, Actual: 5
# Sample Test Data 5983: Predicted: 5, Actual: 5
# Sample Test Data 5984: Predicted: 2, Actual: 2
# Sample Test Data 5985: Predicted: 1, Actual: 1
# Sample Test Data 5986: Predicted: 8, Actual: 5
# Sample Test Data 5987: Predicted: 4, Actual: 4
# Sample Test Data 5988: Predicted: 0, Actual: 0
# Sample Test Data 5989: Predicted: 7, Actual: 7
# Sample Test Data 5990: Predicted: 6, Actual: 6
# Sample Test Data 5991: Predicted: 0, Actual: 0
# Sample Test Data 5992: Predicted: 1, Actual: 1
# Sample Test Data 5993: Predicted: 7, Actual: 7
# Sample Test Data 5994: Predicted: 0, Actual: 0
# Sample Test Data 5995: Predicted: 6, Actual: 6
# Sample Test Data 5996: Predicted: 8, Actual: 8
# Sample Test Data 5997: Predicted: 9, Actual: 9
# Sample Test Data 5998: Predicted: 9, Actual: 5
# Sample Test Data 5999: Predicted: 1, Actual: 1
# Sample Test Data 6000: Predicted: 7, Actual: 7
# Sample Test Data 6001: Predicted: 9, Actual: 9
# Sample Test Data 6002: Predicted: 8, Actual: 8
# Sample Test Data 6003: Predicted: 6, Actual: 6
# Sample Test Data 6004: Predicted: 0, Actual: 0
# Sample Test Data 6005: Predicted: 8, Actual: 8
# Sample Test Data 6006: Predicted: 1, Actual: 1
# Sample Test Data 6007: Predicted: 7, Actual: 7
# Sample Test Data 6008: Predicted: 7, Actual: 7
# Sample Test Data 6009: Predicted: 1, Actual: 1
# Sample Test Data 6010: Predicted: 3, Actual: 3
# Sample Test Data 6011: Predicted: 2, Actual: 2
# Sample Test Data 6012: Predicted: 3, Actual: 3
# Sample Test Data 6013: Predicted: 1, Actual: 1
# Sample Test Data 6014: Predicted: 4, Actual: 4
# Sample Test Data 6015: Predicted: 2, Actual: 2
# Sample Test Data 6016: Predicted: 0, Actual: 0
# Sample Test Data 6017: Predicted: 0, Actual: 0
# Sample Test Data 6018: Predicted: 7, Actual: 7
# Sample Test Data 6019: Predicted: 8, Actual: 8
# Sample Test Data 6020: Predicted: 4, Actual: 4
# Sample Test Data 6021: Predicted: 6, Actual: 6
# Sample Test Data 6022: Predicted: 4, Actual: 4
# Sample Test Data 6023: Predicted: 9, Actual: 9
# Sample Test Data 6024: Predicted: 3, Actual: 3
# Sample Test Data 6025: Predicted: 8, Actual: 8
# Sample Test Data 6026: Predicted: 4, Actual: 4
# Sample Test Data 6027: Predicted: 7, Actual: 7
# ...
# Sample Test Data 9664: Predicted: 0, Actual: 0
# Sample Test Data 9665: Predicted: 7, Actual: 2
# Sample Test Data 9666: Predicted: 6, Actual: 6
# Sample Test Data 9667: Predicted: 0, Actual: 0
# Sample Test Data 9668: Predicted: 8, Actual: 8
# Sample Test Data 9669: Predicted: 9, Actual: 9
# Sample Test Data 9670: Predicted: 4, Actual: 4
# Sample Test Data 9671: Predicted: 3, Actual: 3
# Sample Test Data 9672: Predicted: 5, Actual: 5
# Sample Test Data 9673: Predicted: 4, Actual: 4
# Sample Test Data 9674: Predicted: 8, Actual: 8
# Sample Test Data 9675: Predicted: 1, Actual: 1
# Sample Test Data 9676: Predicted: 5, Actual: 5
# Sample Test Data 9677: Predicted: 9, Actual: 9
# Sample Test Data 9678: Predicted: 0, Actual: 0
# Sample Test Data 9679: Predicted: 6, Actual: 6
# Sample Test Data 9680: Predicted: 6, Actual: 6
# Sample Test Data 9681: Predicted: 3, Actual: 3
# Sample Test Data 9682: Predicted: 8, Actual: 8
# Sample Test Data 9683: Predicted: 1, Actual: 1
# Sample Test Data 9684: Predicted: 4, Actual: 4
# Sample Test Data 9685: Predicted: 7, Actual: 7
# Sample Test Data 9686: Predicted: 5, Actual: 5
# Sample Test Data 9687: Predicted: 2, Actual: 2
# Sample Test Data 9688: Predicted: 0, Actual: 0
# Sample Test Data 9689: Predicted: 0, Actual: 0
# Sample Test Data 9690: Predicted: 1, Actual: 1
# Sample Test Data 9691: Predicted: 7, Actual: 7
# Sample Test Data 9692: Predicted: 8, Actual: 8
# Sample Test Data 9693: Predicted: 4, Actual: 9
# Sample Test Data 9694: Predicted: 6, Actual: 6
# Sample Test Data 9695: Predicted: 8, Actual: 8
# Sample Test Data 9696: Predicted: 8, Actual: 8
# Sample Test Data 9697: Predicted: 2, Actual: 2
# Sample Test Data 9698: Predicted: 3, Actual: 3
# Sample Test Data 9699: Predicted: 6, Actual: 6
# Sample Test Data 9700: Predicted: 1, Actual: 1
# Sample Test Data 9701: Predicted: 2, Actual: 2
# Sample Test Data 9702: Predicted: 9, Actual: 9
# Sample Test Data 9703: Predicted: 5, Actual: 5
# Sample Test Data 9704: Predicted: 2, Actual: 2
# Sample Test Data 9705: Predicted: 0, Actual: 0
# Sample Test Data 9706: Predicted: 1, Actual: 1
# Sample Test Data 9707: Predicted: 2, Actual: 2
# Sample Test Data 9708: Predicted: 3, Actual: 3
# Sample Test Data 9709: Predicted: 4, Actual: 4
# Sample Test Data 9710: Predicted: 5, Actual: 5
# Sample Test Data 9711: Predicted: 6, Actual: 6
# Sample Test Data 9712: Predicted: 7, Actual: 7
# Sample Test Data 9713: Predicted: 8, Actual: 8
# Sample Test Data 9714: Predicted: 9, Actual: 9
# Sample Test Data 9715: Predicted: 0, Actual: 0
# Sample Test Data 9716: Predicted: 1, Actual: 1
# Sample Test Data 9717: Predicted: 3, Actual: 2
# Sample Test Data 9718: Predicted: 3, Actual: 3
# Sample Test Data 9719: Predicted: 4, Actual: 4
# Sample Test Data 9720: Predicted: 5, Actual: 5
# Sample Test Data 9721: Predicted: 6, Actual: 6
# Sample Test Data 9722: Predicted: 7, Actual: 7
# Sample Test Data 9723: Predicted: 8, Actual: 8
# Sample Test Data 9724: Predicted: 9, Actual: 9
# Sample Test Data 9725: Predicted: 0, Actual: 0
# Sample Test Data 9726: Predicted: 1, Actual: 1
# Sample Test Data 9727: Predicted: 2, Actual: 2
# Sample Test Data 9728: Predicted: 3, Actual: 3
# Sample Test Data 9729: Predicted: 4, Actual: 4
# Sample Test Data 9730: Predicted: 6, Actual: 5
# Sample Test Data 9731: Predicted: 6, Actual: 6
# Sample Test Data 9732: Predicted: 7, Actual: 7
# Sample Test Data 9733: Predicted: 8, Actual: 8
# Sample Test Data 9734: Predicted: 9, Actual: 9
# Sample Test Data 9735: Predicted: 7, Actual: 7
# Sample Test Data 9736: Predicted: 4, Actual: 4
# Sample Test Data 9737: Predicted: 6, Actual: 6
# Sample Test Data 9738: Predicted: 1, Actual: 1
# Sample Test Data 9739: Predicted: 4, Actual: 4
# Sample Test Data 9740: Predicted: 0, Actual: 0
# Sample Test Data 9741: Predicted: 9, Actual: 9
# Sample Test Data 9742: Predicted: 9, Actual: 9
# Sample Test Data 9743: Predicted: 3, Actual: 3
# Sample Test Data 9744: Predicted: 7, Actual: 7
# Sample Test Data 9745: Predicted: 8, Actual: 8
# Sample Test Data 9746: Predicted: 4, Actual: 4
# Sample Test Data 9747: Predicted: 7, Actual: 7
# Sample Test Data 9748: Predicted: 5, Actual: 5
# Sample Test Data 9749: Predicted: 8, Actual: 8
# Sample Test Data 9750: Predicted: 5, Actual: 5
# Sample Test Data 9751: Predicted: 3, Actual: 3
# Sample Test Data 9752: Predicted: 2, Actual: 2
# Sample Test Data 9753: Predicted: 2, Actual: 2
# Sample Test Data 9754: Predicted: 0, Actual: 0
# Sample Test Data 9755: Predicted: 5, Actual: 5
# Sample Test Data 9756: Predicted: 8, Actual: 8
# Sample Test Data 9757: Predicted: 6, Actual: 6
# Sample Test Data 9758: Predicted: 0, Actual: 0
# Sample Test Data 9759: Predicted: 3, Actual: 3
# Sample Test Data 9760: Predicted: 8, Actual: 8
# Sample Test Data 9761: Predicted: 1, Actual: 1
# Sample Test Data 9762: Predicted: 0, Actual: 0
# Sample Test Data 9763: Predicted: 3, Actual: 3
# Sample Test Data 9764: Predicted: 0, Actual: 0
# Sample Test Data 9765: Predicted: 4, Actual: 4
# Sample Test Data 9766: Predicted: 7, Actual: 7
# Sample Test Data 9767: Predicted: 4, Actual: 4
# Sample Test Data 9768: Predicted: 9, Actual: 9
# Sample Test Data 9769: Predicted: 0, Actual: 2
# Sample Test Data 9770: Predicted: 9, Actual: 9
# Sample Test Data 9771: Predicted: 0, Actual: 5
# Sample Test Data 9772: Predicted: 7, Actual: 7
# Sample Test Data 9773: Predicted: 1, Actual: 1
# Sample Test Data 9774: Predicted: 7, Actual: 7
# Sample Test Data 9775: Predicted: 1, Actual: 1
# Sample Test Data 9776: Predicted: 6, Actual: 6
# Sample Test Data 9777: Predicted: 6, Actual: 6
# Sample Test Data 9778: Predicted: 0, Actual: 5
# Sample Test Data 9779: Predicted: 6, Actual: 6
# Sample Test Data 9780: Predicted: 8, Actual: 2
# Sample Test Data 9781: Predicted: 8, Actual: 8
# Sample Test Data 9782: Predicted: 7, Actual: 7
# Sample Test Data 9783: Predicted: 6, Actual: 6
# Sample Test Data 9784: Predicted: 4, Actual: 4
# Sample Test Data 9785: Predicted: 9, Actual: 9
# Sample Test Data 9786: Predicted: 9, Actual: 9
# Sample Test Data 9787: Predicted: 5, Actual: 5
# Sample Test Data 9788: Predicted: 3, Actual: 3
# Sample Test Data 9789: Predicted: 7, Actual: 7
# Sample Test Data 9790: Predicted: 4, Actual: 4
# Sample Test Data 9791: Predicted: 3, Actual: 3
# Sample Test Data 9792: Predicted: 0, Actual: 0
# Sample Test Data 9793: Predicted: 4, Actual: 4
# Sample Test Data 9794: Predicted: 6, Actual: 6
# Sample Test Data 9795: Predicted: 6, Actual: 6
# Sample Test Data 9796: Predicted: 1, Actual: 1
# Sample Test Data 9797: Predicted: 1, Actual: 1
# Sample Test Data 9798: Predicted: 3, Actual: 3
# Sample Test Data 9799: Predicted: 2, Actual: 2
# Sample Test Data 9800: Predicted: 1, Actual: 1
# Sample Test Data 9801: Predicted: 0, Actual: 0
# Sample Test Data 9802: Predicted: 0, Actual: 0
# Sample Test Data 9803: Predicted: 1, Actual: 1
# Sample Test Data 9804: Predicted: 2, Actual: 2
# Sample Test Data 9805: Predicted: 3, Actual: 3
# Sample Test Data 9806: Predicted: 4, Actual: 4
# Sample Test Data 9807: Predicted: 7, Actual: 7
# Sample Test Data 9808: Predicted: 8, Actual: 8
# Sample Test Data 9809: Predicted: 9, Actual: 9
# Sample Test Data 9810: Predicted: 0, Actual: 0
# Sample Test Data 9811: Predicted: 1, Actual: 1
# Sample Test Data 9812: Predicted: 8, Actual: 2
# Sample Test Data 9813: Predicted: 3, Actual: 3
# Sample Test Data 9814: Predicted: 4, Actual: 4
# Sample Test Data 9815: Predicted: 5, Actual: 5
# Sample Test Data 9816: Predicted: 6, Actual: 6
# Sample Test Data 9817: Predicted: 7, Actual: 7
# Sample Test Data 9818: Predicted: 8, Actual: 8
# Sample Test Data 9819: Predicted: 0, Actual: 0
# Sample Test Data 9820: Predicted: 1, Actual: 1
# Sample Test Data 9821: Predicted: 2, Actual: 2
# Sample Test Data 9822: Predicted: 3, Actual: 3
# Sample Test Data 9823: Predicted: 4, Actual: 4
# Sample Test Data 9824: Predicted: 7, Actual: 7
# Sample Test Data 9825: Predicted: 8, Actual: 8
# Sample Test Data 9826: Predicted: 9, Actual: 9
# Sample Test Data 9827: Predicted: 0, Actual: 0
# Sample Test Data 9828: Predicted: 8, Actual: 8
# Sample Test Data 9829: Predicted: 3, Actual: 3
# Sample Test Data 9830: Predicted: 9, Actual: 9
# Sample Test Data 9831: Predicted: 5, Actual: 5
# Sample Test Data 9832: Predicted: 5, Actual: 5
# Sample Test Data 9833: Predicted: 2, Actual: 2
# Sample Test Data 9834: Predicted: 6, Actual: 6
# Sample Test Data 9835: Predicted: 8, Actual: 8
# Sample Test Data 9836: Predicted: 4, Actual: 4
# Sample Test Data 9837: Predicted: 1, Actual: 1
# Sample Test Data 9838: Predicted: 7, Actual: 7
# Sample Test Data 9839: Predicted: 1, Actual: 1
# Sample Test Data 9840: Predicted: 7, Actual: 2
# Sample Test Data 9841: Predicted: 3, Actual: 3
# Sample Test Data 9842: Predicted: 5, Actual: 5
# Sample Test Data 9843: Predicted: 6, Actual: 6
# Sample Test Data 9844: Predicted: 9, Actual: 9
# Sample Test Data 9845: Predicted: 1, Actual: 1
# Sample Test Data 9846: Predicted: 1, Actual: 1
# Sample Test Data 9847: Predicted: 1, Actual: 1
# Sample Test Data 9848: Predicted: 2, Actual: 2
# Sample Test Data 9849: Predicted: 1, Actual: 1
# Sample Test Data 9850: Predicted: 2, Actual: 2
# Sample Test Data 9851: Predicted: 0, Actual: 0
# Sample Test Data 9852: Predicted: 7, Actual: 7
# Sample Test Data 9853: Predicted: 7, Actual: 7
# Sample Test Data 9854: Predicted: 5, Actual: 5
# Sample Test Data 9855: Predicted: 8, Actual: 8
# Sample Test Data 9856: Predicted: 2, Actual: 2
# Sample Test Data 9857: Predicted: 9, Actual: 9
# Sample Test Data 9858: Predicted: 8, Actual: 8
# Sample Test Data 9859: Predicted: 6, Actual: 6
# Sample Test Data 9860: Predicted: 7, Actual: 7
# Sample Test Data 9861: Predicted: 3, Actual: 3
# Sample Test Data 9862: Predicted: 4, Actual: 4
# Sample Test Data 9863: Predicted: 6, Actual: 6
# Sample Test Data 9864: Predicted: 8, Actual: 8
# Sample Test Data 9865: Predicted: 7, Actual: 7
# Sample Test Data 9866: Predicted: 0, Actual: 0
# Sample Test Data 9867: Predicted: 4, Actual: 4
# Sample Test Data 9868: Predicted: 2, Actual: 2
# Sample Test Data 9869: Predicted: 7, Actual: 7
# Sample Test Data 9870: Predicted: 7, Actual: 7
# Sample Test Data 9871: Predicted: 5, Actual: 5
# Sample Test Data 9872: Predicted: 4, Actual: 4
# Sample Test Data 9873: Predicted: 3, Actual: 3
# Sample Test Data 9874: Predicted: 4, Actual: 4
# Sample Test Data 9875: Predicted: 2, Actual: 2
# Sample Test Data 9876: Predicted: 8, Actual: 8
# Sample Test Data 9877: Predicted: 1, Actual: 1
# Sample Test Data 9878: Predicted: 5, Actual: 5
# Sample Test Data 9879: Predicted: 1, Actual: 1
# Sample Test Data 9880: Predicted: 0, Actual: 0
# Sample Test Data 9881: Predicted: 2, Actual: 2
# Sample Test Data 9882: Predicted: 3, Actual: 3
# Sample Test Data 9883: Predicted: 3, Actual: 3
# Sample Test Data 9884: Predicted: 5, Actual: 5
# Sample Test Data 9885: Predicted: 7, Actual: 7
# Sample Test Data 9886: Predicted: 0, Actual: 0
# Sample Test Data 9887: Predicted: 6, Actual: 6
# Sample Test Data 9888: Predicted: 8, Actual: 8
# Sample Test Data 9889: Predicted: 6, Actual: 6
# Sample Test Data 9890: Predicted: 3, Actual: 3
# Sample Test Data 9891: Predicted: 9, Actual: 9
# Sample Test Data 9892: Predicted: 4, Actual: 9
# Sample Test Data 9893: Predicted: 8, Actual: 8
# Sample Test Data 9894: Predicted: 2, Actual: 2
# Sample Test Data 9895: Predicted: 7, Actual: 7
# Sample Test Data 9896: Predicted: 7, Actual: 7
# Sample Test Data 9897: Predicted: 1, Actual: 1
# Sample Test Data 9898: Predicted: 0, Actual: 0
# Sample Test Data 9899: Predicted: 1, Actual: 1
# Sample Test Data 9900: Predicted: 7, Actual: 7
# Sample Test Data 9901: Predicted: 8, Actual: 8
# Sample Test Data 9902: Predicted: 9, Actual: 9
# Sample Test Data 9903: Predicted: 0, Actual: 0
# Sample Test Data 9904: Predicted: 1, Actual: 1
# Sample Test Data 9905: Predicted: 2, Actual: 2
# Sample Test Data 9906: Predicted: 9, Actual: 3
# Sample Test Data 9907: Predicted: 4, Actual: 4
# Sample Test Data 9908: Predicted: 5, Actual: 5
# Sample Test Data 9909: Predicted: 6, Actual: 6
# Sample Test Data 9910: Predicted: 7, Actual: 7
# Sample Test Data 9911: Predicted: 8, Actual: 8
# Sample Test Data 9912: Predicted: 0, Actual: 0
# Sample Test Data 9913: Predicted: 1, Actual: 1
# Sample Test Data 9914: Predicted: 2, Actual: 2
# Sample Test Data 9915: Predicted: 3, Actual: 3
# Sample Test Data 9916: Predicted: 4, Actual: 4
# Sample Test Data 9917: Predicted: 7, Actual: 7
# Sample Test Data 9918: Predicted: 8, Actual: 8
# Sample Test Data 9919: Predicted: 9, Actual: 9
# Sample Test Data 9920: Predicted: 7, Actual: 7
# Sample Test Data 9921: Predicted: 8, Actual: 8
# Sample Test Data 9922: Predicted: 6, Actual: 6
# Sample Test Data 9923: Predicted: 4, Actual: 4
# Sample Test Data 9924: Predicted: 1, Actual: 1
# Sample Test Data 9925: Predicted: 9, Actual: 9
# Sample Test Data 9926: Predicted: 3, Actual: 3
# Sample Test Data 9927: Predicted: 8, Actual: 8
# Sample Test Data 9928: Predicted: 4, Actual: 4
# Sample Test Data 9929: Predicted: 4, Actual: 4
# Sample Test Data 9930: Predicted: 7, Actual: 7
# Sample Test Data 9931: Predicted: 0, Actual: 0
# Sample Test Data 9932: Predicted: 1, Actual: 1
# Sample Test Data 9933: Predicted: 9, Actual: 9
# Sample Test Data 9934: Predicted: 2, Actual: 2
# Sample Test Data 9935: Predicted: 8, Actual: 8
# Sample Test Data 9936: Predicted: 7, Actual: 7
# Sample Test Data 9937: Predicted: 8, Actual: 8
# Sample Test Data 9938: Predicted: 2, Actual: 2
# Sample Test Data 9939: Predicted: 6, Actual: 6
# Sample Test Data 9940: Predicted: 0, Actual: 0
# Sample Test Data 9941: Predicted: 6, Actual: 6
# Sample Test Data 9942: Predicted: 5, Actual: 5
# Sample Test Data 9943: Predicted: 3, Actual: 3
# Sample Test Data 9944: Predicted: 3, Actual: 3
# Sample Test Data 9945: Predicted: 3, Actual: 3
# Sample Test Data 9946: Predicted: 9, Actual: 9
# Sample Test Data 9947: Predicted: 1, Actual: 1
# Sample Test Data 9948: Predicted: 4, Actual: 4
# Sample Test Data 9949: Predicted: 0, Actual: 0
# Sample Test Data 9950: Predicted: 6, Actual: 6
# Sample Test Data 9951: Predicted: 1, Actual: 1
# Sample Test Data 9952: Predicted: 0, Actual: 0
# Sample Test Data 9953: Predicted: 0, Actual: 0
# Sample Test Data 9954: Predicted: 6, Actual: 6
# Sample Test Data 9955: Predicted: 2, Actual: 2
# Sample Test Data 9956: Predicted: 1, Actual: 1
# Sample Test Data 9957: Predicted: 1, Actual: 1
# Sample Test Data 9958: Predicted: 7, Actual: 7
# Sample Test Data 9959: Predicted: 7, Actual: 7
# Sample Test Data 9960: Predicted: 8, Actual: 8
# Sample Test Data 9961: Predicted: 4, Actual: 4
# Sample Test Data 9962: Predicted: 6, Actual: 6
# Sample Test Data 9963: Predicted: 0, Actual: 0
# Sample Test Data 9964: Predicted: 7, Actual: 7
# Sample Test Data 9965: Predicted: 0, Actual: 0
# Sample Test Data 9966: Predicted: 3, Actual: 3
# Sample Test Data 9967: Predicted: 6, Actual: 6
# Sample Test Data 9968: Predicted: 8, Actual: 8
# Sample Test Data 9969: Predicted: 7, Actual: 7
# Sample Test Data 9970: Predicted: 1, Actual: 1
# Sample Test Data 9971: Predicted: 5, Actual: 5
# Sample Test Data 9972: Predicted: 2, Actual: 2
# Sample Test Data 9973: Predicted: 4, Actual: 4
# Sample Test Data 9974: Predicted: 9, Actual: 9
# Sample Test Data 9975: Predicted: 4, Actual: 4
# Sample Test Data 9976: Predicted: 3, Actual: 3
# Sample Test Data 9977: Predicted: 6, Actual: 6
# Sample Test Data 9978: Predicted: 4, Actual: 4
# Sample Test Data 9979: Predicted: 1, Actual: 1
# Sample Test Data 9980: Predicted: 7, Actual: 7
# Sample Test Data 9981: Predicted: 2, Actual: 2
# Sample Test Data 9982: Predicted: 6, Actual: 6
# Sample Test Data 9983: Predicted: 5, Actual: 5
# Sample Test Data 9984: Predicted: 0, Actual: 0
# Sample Test Data 9985: Predicted: 1, Actual: 1
# Sample Test Data 9986: Predicted: 2, Actual: 2
# Sample Test Data 9987: Predicted: 3, Actual: 3
# Sample Test Data 9988: Predicted: 4, Actual: 4
# Sample Test Data 9989: Predicted: 5, Actual: 5
# Sample Test Data 9990: Predicted: 6, Actual: 6
# Sample Test Data 9991: Predicted: 7, Actual: 7
# Sample Test Data 9992: Predicted: 8, Actual: 8
# Sample Test Data 9993: Predicted: 9, Actual: 9
# Sample Test Data 9994: Predicted: 0, Actual: 0
# Sample Test Data 9995: Predicted: 1, Actual: 1
# Sample Test Data 9996: Predicted: 2, Actual: 2
# Sample Test Data 9997: Predicted: 3, Actual: 3
# Sample Test Data 9998: Predicted: 4, Actual: 4
# Sample Test Data 9999: Predicted: 5, Actual: 5
# Sample Test Data 10000: Predicted: 6, Actual: 6
#
# ========= Summary =========
# Training Set Size: 60000
# Test Set Size: 10000
# Final Error Rate: 1.98%
# Model Accuracy: 98.02%
# ===========================
